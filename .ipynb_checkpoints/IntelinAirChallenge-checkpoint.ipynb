# %% [markdown]
# Welcome to my attempt at the Intelinair CVPR challenge! The goal is to do semantic segmentation of the images provided. I'm going to attempt to recreate a slimmed-down version of the model in the paper.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import tensorflow as tf
import tensorflow.keras
from tensorflow.keras import optimizers
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten 
from tensorflow.keras.layers import Conv2D, AveragePooling2D, MaxPooling2D, GlobalMaxPooling2D, ELU, Conv3D, ConvLSTM2D 
from tensorflow.keras.layers import UpSampling2D, Concatenate, Multiply
from tensorflow.keras.preprocessing import image
from keras_preprocessing.image import ImageDataGenerator
from tensorflow.python.keras.utils import layer_utils
from tensorflow.python.keras.utils.data_utils import get_file
from tensorflow.keras.applications.imagenet_utils import preprocess_input
from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.model_selection import train_test_split
import tensorflow.keras.backend as K
import random
import cv2
import sys

# %%
input_img0_names = []
input_img1_names = []
input_img2_names = []
boundary_mask_names = []
nutrient_mask_names = []

HEIGHT = 256
WIDTH = 256
CHANNELS = 3
BATCH_SIZE = 1
src_dir = '/home/garrett/Documents/IntelinAirData/Longitudinal_Nutrient_Deficiency'

for i in range(1,387):
    filestring = str(i).zfill(3)
    input_img0_names.append(os.path.join(src_dir, f'field_{filestring}/image_i0.png'))
    input_img1_names.append(os.path.join(src_dir, f'field_{filestring}/image_i1.png'))
    input_img2_names.append(os.path.join(src_dir, f'field_{filestring}/image_i2.png'))
    boundary_mask_names.append(os.path.join(src_dir, f'field_{filestring}/bounday_mask.png'))
    nutrient_mask_names.append(os.path.join(src_dir, f'field_{filestring}/nutrient_mask_g0.png'))
    
df = pd.DataFrame({'image_0':input_img0_names , 'image_1':input_img1_names, 'image_2':input_img2_names, 
                   'boundary_mask':boundary_mask_names, 'nutrient_mask':nutrient_mask_names})
#df.reset_index(drop=True, inplace=True)
df.head(5)

XY_train,XY_valtest = train_test_split(df, train_size=0.8, random_state=0)
XY_val, XY_test = train_test_split(XY_valtest, train_size=0.5, random_state=0)
XY_train.reset_index(drop=True, inplace=True)
XY_val.reset_index(drop=True, inplace=True)
XY_test.reset_index(drop=True, inplace=True)
XY_train.head(5)
# Out:
#                                              image_0  \
# 0  /home/garrett/Documents/IntelinAirData/Longitu...
# 1  /home/garrett/Documents/IntelinAirData/Longitu...
# 2  /home/garrett/Documents/IntelinAirData/Longitu...
# 3  /home/garrett/Documents/IntelinAirData/Longitu...
# 4  /home/garrett/Documents/IntelinAirData/Longitu...
#
#                                              image_1  \
# 0  /home/garrett/Documents/IntelinAirData/Longitu...
# 1  /home/garrett/Documents/IntelinAirData/Longitu...
# 2  /home/garrett/Documents/IntelinAirData/Longitu...
# 3  /home/garrett/Documents/IntelinAirData/Longitu...
# 4  /home/garrett/Documents/IntelinAirData/Longitu...
#
#                                              image_2  \
# 0  /home/garrett/Documents/IntelinAirData/Longitu...
# 1  /home/garrett/Documents/IntelinAirData/Longitu...
# 2  /home/garrett/Documents/IntelinAirData/Longitu...
# 3  /home/garrett/Documents/IntelinAirData/Longitu...
# 4  /home/garrett/Documents/IntelinAirData/Longitu...
#
#                                        boundary_mask  \
# 0  /home/garrett/Documents/IntelinAirData/Longitu...
# 1  /home/garrett/Documents/IntelinAirData/Longitu...
# 2  /home/garrett/Documents/IntelinAirData/Longitu...
# 3  /home/garrett/Documents/IntelinAirData/Longitu...
# 4  /home/garrett/Documents/IntelinAirData/Longitu...
#
#                                        nutrient_mask
# 0  /home/garrett/Documents/IntelinAirData/Longitu...
# 1  /home/garrett/Documents/IntelinAirData/Longitu...
# 2  /home/garrett/Documents/IntelinAirData/Longitu...
# 3  /home/garrett/Documents/IntelinAirData/Longitu...
# 4  /home/garrett/Documents/IntelinAirData/Longitu...

# %%
index = random.randint(0, len(XY_train)-1)
img = cv2.imread(XY_train.loc[index].at["image_0"])
mask = cv2.imread(XY_train.loc[index].at["nutrient_mask"])
bdymask = cv2.imread(XY_train.loc[index].at["boundary_mask"])

plt.figure(figsize=(20, 6))
plt.subplot(131)
plt.imshow(img)
plt.title('Original')
plt.axis('off')

plt.subplot(132)
plt.imshow(mask)
plt.title('Mask')
plt.axis('off')

plt.subplot(133)
plt.imshow(bdymask)
plt.title('Boundary Mask')
plt.axis('off')
# Out:
# (-0.5, 1487.5, 1087.5, -0.5)

# %%
def myGenerator(generator1,generator2,generator3,boundgenerator,outgenerator):
        while True:
            for x0,x1,x2,bound,y1 in zip(generator1,generator2,generator3,boundgenerator,outgenerator):
                #print(y1[:,:,:,2].shape)
                yield ([x0,x1,x2,bound[:,:,:,2]], y1)

# %%
image0_train_datagen = ImageDataGenerator(rescale=1./255.)
image1_train_datagen = ImageDataGenerator(rescale=1./255.)
image2_train_datagen = ImageDataGenerator(rescale=1./255.)
mask_train_datagen = ImageDataGenerator(rescale=1./255.)
boundary_train_datagen = ImageDataGenerator(rescale=1./255.)

image0_val_datagen = ImageDataGenerator(rescale=1./255.)
image1_val_datagen = ImageDataGenerator(rescale=1./255.)
image2_val_datagen = ImageDataGenerator(rescale=1./255.)
mask_val_datagen = ImageDataGenerator(rescale=1./255.)
boundary_val_datagen = ImageDataGenerator(rescale=1./255.)

image0_test_datagen = ImageDataGenerator(rescale=1./255.)
image1_test_datagen = ImageDataGenerator(rescale=1./255.)
image2_test_datagen = ImageDataGenerator(rescale=1./255.)
mask_test_datagen = ImageDataGenerator(rescale=1./255.)
boundary_test_datagen = ImageDataGenerator(rescale=1./255.)

# %%
seed = 1

image0_train_generator = image0_train_datagen.flow_from_dataframe(
    dataframe=XY_train,
    x_col="image_0",
    class_mode=None,
    horizontal_flip=True,
    vertical_flip=True,
    target_size = (WIDTH, HEIGHT),
    batch_size = BATCH_SIZE,
    seed=seed)

image1_train_generator = image1_train_datagen.flow_from_dataframe(
    dataframe=XY_train,
    x_col="image_1",
    class_mode=None,
    horizontal_flip=True,
    vertical_flip=True,
    target_size = (WIDTH, HEIGHT),
    batch_size = BATCH_SIZE,
    seed=seed)

image2_train_generator = image2_train_datagen.flow_from_dataframe(
    dataframe=XY_train,
    x_col="image_2",
    class_mode=None,
    horizontal_flip=True,
    vertical_flip=True,
    target_size = (WIDTH, HEIGHT),
    batch_size = BATCH_SIZE,
    seed=seed)

mask_train_generator = mask_train_datagen.flow_from_dataframe(
    dataframe=XY_train,
    x_col="nutrient_mask",
    class_mode=None,
    horizontal_flip=True,
    vertical_flip=True,
    target_size = (WIDTH, HEIGHT),
    batch_size = BATCH_SIZE,
    seed=seed)

boundary_train_generator = boundary_train_datagen.flow_from_dataframe(
    dataframe=XY_train,
    x_col="boundary_mask",
    class_mode=None,
    horizontal_flip=True,
    vertical_flip=True,
    target_size = (WIDTH, HEIGHT),
    batch_size = BATCH_SIZE,
    seed=seed)

# combine generators into one which yields image and masks
train_generator = myGenerator(image0_train_generator, image1_train_generator,
                              image2_train_generator, boundary_train_generator, mask_train_generator)
# Out:
# Found 308 validated image filenames.
# Found 308 validated image filenames.
# Found 308 validated image filenames.
# Found 308 validated image filenames.
# Found 308 validated image filenames.

# %%
seed = 1

image0_val_generator = image0_val_datagen.flow_from_dataframe(
    dataframe=XY_val,
    x_col="image_0",
    class_mode=None,
    horizontal_flip=True,
    vertical_flip=True,
    target_size = (WIDTH, HEIGHT),
    batch_size = BATCH_SIZE,
    seed=seed)

image1_val_generator = image1_val_datagen.flow_from_dataframe(
    dataframe=XY_val,
    x_col="image_1",
    class_mode=None,
    horizontal_flip=True,
    vertical_flip=True,
    target_size = (WIDTH, HEIGHT),
    batch_size = BATCH_SIZE,
    seed=seed)

image2_val_generator = image2_val_datagen.flow_from_dataframe(
    dataframe=XY_val,
    x_col="image_2",
    class_mode=None,
    horizontal_flip=True,
    vertical_flip=True,
    target_size = (WIDTH, HEIGHT),
    batch_size = BATCH_SIZE,
    seed=seed)

mask_val_generator = mask_val_datagen.flow_from_dataframe(
    dataframe=XY_val,
    x_col="nutrient_mask",
    class_mode=None,
    horizontal_flip=True,
    vertical_flip=True,
    target_size = (WIDTH, HEIGHT),
    batch_size = BATCH_SIZE,
    seed=seed)


boundary_val_generator = boundary_val_datagen.flow_from_dataframe(
    dataframe=XY_val,
    x_col="boundary_mask",
    class_mode=None,
    horizontal_flip=True,
    vertical_flip=True,
    target_size = (WIDTH, HEIGHT),
    batch_size = BATCH_SIZE,
    seed=seed)

# combine generators into one which yields image and masks
val_generator = myGenerator(image0_val_generator, image1_val_generator,
                              image2_val_generator, boundary_val_generator, mask_val_generator)
# Out:
# Found 39 validated image filenames.
# Found 39 validated image filenames.
# Found 39 validated image filenames.
# Found 39 validated image filenames.
# Found 39 validated image filenames.

# %%
seed = 1

image0_test_generator = image0_test_datagen.flow_from_dataframe(
    dataframe=XY_test,
    x_col="image_0",
    class_mode=None,
    horizontal_flip=True,
    vertical_flip=True,
    target_size = (WIDTH, HEIGHT),
    batch_size = BATCH_SIZE,
    seed=seed)

image1_test_generator = image1_test_datagen.flow_from_dataframe(
    dataframe=XY_test,
    x_col="image_1",
    class_mode=None,
    horizontal_flip=True,
    vertical_flip=True,
    target_size = (WIDTH, HEIGHT),
    batch_size = BATCH_SIZE,
    seed=seed)

image2_test_generator = image2_test_datagen.flow_from_dataframe(
    dataframe=XY_test,
    x_col="image_2",
    class_mode=None,
    horizontal_flip=True,
    vertical_flip=True,
    target_size = (WIDTH, HEIGHT),
    batch_size = BATCH_SIZE,
    seed=seed)

mask_test_generator = mask_test_datagen.flow_from_dataframe(
    dataframe=XY_test,
    x_col="nutrient_mask",
    class_mode=None,
    horizontal_flip=True,
    vertical_flip=True,
    target_size = (WIDTH, HEIGHT),
    batch_size = BATCH_SIZE,
    seed=seed)


boundary_test_generator = boundary_test_datagen.flow_from_dataframe(
    dataframe=XY_test,
    x_col="boundary_mask",
    class_mode=None,
    horizontal_flip=True,
    vertical_flip=True,
    target_size = (WIDTH, HEIGHT),
    batch_size = BATCH_SIZE,
    seed=seed)

# combine generators into one which yields image and masks
test_generator = myGenerator(image0_test_generator, image1_test_generator,
                              image2_test_generator, boundary_test_generator, mask_test_generator)
# Out:
# Found 39 validated image filenames.
# Found 39 validated image filenames.
# Found 39 validated image filenames.
# Found 39 validated image filenames.
# Found 39 validated image filenames.

# %%
#Given that I'm training three U-Nets in parallel, I can only afford a few filters for each layer.

def UNet(image_input, boundary_input):

    ''' ~~~~~~~~~~~~~~~~~~~ ENCODING LAYERS ~~~~~~~~~~~~~~~~~~~ '''

    c1 = Conv2D(8, kernel_size=(3,3), kernel_initializer='he_normal', padding = 'same')(image_input)
    c1 = ELU()(c1)
    c1 = BatchNormalization()(c1)
    c1 = Conv2D(8, kernel_size=(3,3), kernel_initializer='he_normal', padding = 'same')(c1)
    c1 = ELU()(c1)
    c1 = BatchNormalization()(c1)
    
    p1 = MaxPooling2D((2,2))(c1)

    c2 = Conv2D(8*2, kernel_size=(3,3), kernel_initializer='he_normal', padding = 'same')(p1)
    c2 = ELU()(c2)
    c2 = BatchNormalization()(c2)
    c2 = Conv2D(8*2, kernel_size=(3,3), kernel_initializer='he_normal', padding = 'same')(c2)
    c2 = ELU()(c2)
    c2 = BatchNormalization()(c2)
    p2 = MaxPooling2D((2,2))(c2)
    

    c3 = Conv2D(8*4, kernel_size=(3,3), kernel_initializer='he_normal', padding = 'same')(p2)
    c3 = ELU()(c3)
    c3 = BatchNormalization()(c3)
    c3 = Conv2D(8*2, kernel_size=(1,1), kernel_initializer='he_normal', padding = 'same')(c3)
    c3 = ELU()(c3)
    c3 = BatchNormalization()(c3)
    c3 = Conv2D(8*4, kernel_size=(3,3), kernel_initializer='he_normal', padding = 'same')(c3)
    c3 = ELU()(c3)
    c3 = BatchNormalization()(c3)

    p3 = MaxPooling2D((2,2))(c3)

    c4 = Conv2D(8*6, kernel_size=(3,3), kernel_initializer='he_normal', padding = 'same')(p3)
    c4 = ELU()(c4)
    c4 = BatchNormalization()(c4)
    c4 = Conv2D(8*4, kernel_size=(1,1), kernel_initializer='he_normal', padding = 'same')(c4)
    c4 = ELU()(c4)
    c4 = BatchNormalization()(c4)
    c4 = Conv2D(8*6, kernel_size=(3,3), kernel_initializer='he_normal', padding = 'same')(c4)
    c4 = ELU()(c4)
    c4 = BatchNormalization()(c4)

    p4 = MaxPooling2D((2,2))(c4)

    c5 = Conv2D(8*6, kernel_size=(3,3), kernel_initializer='he_normal', padding = 'same')(p4)
    c5 = ELU()(c5)
    c5 = BatchNormalization()(c5)


    ''' ~~~~~~~~~~~~~~~~~~~ DECODING LAYERS ~~~~~~~~~~~~~~~~~~~ '''

    u1 = UpSampling2D((2,2))(c5)
    concat1 = Concatenate()([c4, u1])

    c6 = Conv2D(8*4, kernel_size=(3,3), kernel_initializer='he_normal', padding = 'same')(concat1)
    c6 = ELU()(c6)
    c6 = BatchNormalization()(c6)
    c6 = Conv2D(8*4, kernel_size=(3,3), kernel_initializer='he_normal', padding = 'same')(c6)
    c6 = ELU()(c6)
    c6 = BatchNormalization()(c6)


    u2 = UpSampling2D((2,2))(c6)
    concat2 = Concatenate()([c3, u2])

    c7 = Conv2D(8*2, kernel_size=(3,3), kernel_initializer='he_normal', padding = 'same')(concat2)
    c7 = ELU()(c7)
    c7 = BatchNormalization()(c7)
    c7 = Conv2D(8*2, kernel_size=(3,3), kernel_initializer='he_normal', padding = 'same')(c7)
    c7 = ELU()(c7)
    c7 = BatchNormalization()(c7)

    u3 = UpSampling2D((2,2))(c7)
    concat3 = Concatenate()([c2, u3])

    c8 = Conv2D(8, kernel_size=(3,3), kernel_initializer='he_normal', padding = 'same')(concat3)
    c8 = ELU()(c8)
    c8 = BatchNormalization()(c8)
    c8 = Conv2D(8, kernel_size=(3,3), kernel_initializer='he_normal', padding = 'same')(c8)
    c8 = ELU()(c8)
    c8 = BatchNormalization()(c8)

    u4 = UpSampling2D((2,2))(c8)
    concat4 = Concatenate()([c1, u4])

    c9 = Conv2D(4, kernel_size = (1,1), kernel_initializer='he_normal', padding = 'same')(concat4)
    c9 = ELU()(c9)
    c9 = BatchNormalization()(c9)

    mask_out = Conv2D(1, (1,1), kernel_initializer='he_normal', padding = 'same', activation = 'sigmoid')(c9)
    multmask = Multiply()([mask_out, boundary_input])
    
    return multmask

# %%
def ConvLSTM(movieIn, boundary_input):
    
    x = ConvLSTM2D(
    filters=16,
    kernel_size=(5, 5),
    padding="same",
    return_sequences=True,
    activation="elu",
    )(movieIn)

    x = BatchNormalization()(x)

    x = ConvLSTM2D(
    filters=16,
    kernel_size=(3, 3),
    padding="same",
    return_sequences=True,
    activation="elu",
    )(x)
    
    x = BatchNormalization()(x)
    
    x = ConvLSTM2D(
    filters=16,
    kernel_size=(1, 1),
    padding="same",
    return_sequences=True,
    activation="elu",
    )(x)
    
    x = BatchNormalization()(x)
    
    lastmask = Conv3D(
    filters=1,
    kernel_size=(3, 3, 3),
    activation="sigmoid",
    padding="same"
    )(x)
    
    P0 = Multiply()([boundary_input,lastmask[:,0,:,:,:]])
    P1 = Multiply()([boundary_input,lastmask[:,1,:,:,:]])
    P2 = Multiply()([boundary_input,lastmask[:,2,:,:,:]])
    
    outmask = Concatenate()([P0,P1,P2])
    
    return outmask

# %%
def LastOnlyModel():

    image0 = Input(shape=(HEIGHT, WIDTH, CHANNELS), name = 'img0_input')
    image1 = Input(shape=(HEIGHT, WIDTH, CHANNELS), name = 'img1_input')
    image2 = Input(shape=(HEIGHT, WIDTH, CHANNELS), name = 'img2_input')
    boundary = Input(shape=(HEIGHT, WIDTH, 1), name = 'boundary_input')
    outmask= UNet(image2, boundary)
    
    model = Model(inputs = [image0,image1,image2, boundary], outputs = outmask, name='SemanticSegModelOnlyLast')

    return model

# %%
def FullModel():

    image0 = Input(shape=(HEIGHT, WIDTH, CHANNELS), name = 'img0_input')
    image1 = Input(shape=(HEIGHT, WIDTH, CHANNELS), name = 'img1_input')
    image2 = Input(shape=(HEIGHT, WIDTH, CHANNELS), name = 'img2_input')
    boundary = Input(shape=(HEIGHT, WIDTH, 1), name = 'boundary_input')
    
    X1= UNet(image0, boundary)
    X2= UNet(image1, boundary)
    X3= UNet(image2, boundary)

    
    X1 = tf.keras.backend.expand_dims(X1,axis=1)
    X2 = tf.keras.backend.expand_dims(X2,axis=1)
    X3 = tf.keras.backend.expand_dims(X3,axis=1)
    movie=Concatenate(axis=1)([X1, X2, X3])

    
    outmask = ConvLSTM(movie, boundary)
    print(outmask.shape)                   
    model = Model(inputs = [image0,image1,image2, boundary], outputs = outmask, name='SemanticSegModel')

    
    return model

# %%
def lrfn(epoch):
    if epoch > 15:
        return 2e-6
    elif epoch > 25:
        return 1e-6
    return 1e-6

# %%
# Learning rate callback
lr_callback = tf.keras.callbacks.LearningRateScheduler(lambda step: lrfn(step))
# Model checkpoint, saves weights if val loss reduces
checkpoint = tf.keras.callbacks.ModelCheckpoint('model.h5', 'val_loss', save_best_only=True, save_weights_only=True, verbose=1)

# %%
def tversky_loss(targets, inputs, alpha=1, beta=1, numLabels=2):

    tversky = 0
    #flatten label and prediction tensors
    inputs = K.flatten(inputs)
    targets = K.flatten(targets)
        
    #True Positives, False Positives & False Negatives
    TP = K.sum((inputs * targets))
    FP = K.sum(((1-targets) * inputs))
    FN = K.sum((targets * (1-inputs)))
    TN = K.sum(((1-inputs) * (1-targets)))    
    tversky= ((TP) / (TP + alpha*FP + beta*FN))+ ((TN) / (TN + alpha*FN + beta*FP)) 
    return (2 - tversky)

    
def focal_loss(targets, inputs, numLabels=2):

    inputs = K.flatten(inputs)
    targets = K.flatten(targets)
    inputs2 = K.flatten(1-inputs)
    targets2 = K.flatten(1-targets)
               
    BCE = K.binary_crossentropy(targets, inputs)
    BCE_EXP = K.exp(-BCE)
    BCE2 = K.binary_crossentropy(targets2, inputs2)
    BCE_EXP2 = K.exp(-BCE2)           
               
    focal_loss = K.mean(K.pow((1-BCE_EXP), 2) * BCE)+K.mean(K.pow((1-BCE_EXP2), 2) * BCE2)
    return focal_loss
            
def hybrid_loss(targets, inputs, _lambda_ = 1):
    tversky= tversky_loss(targets, inputs)
    focal=focal_loss(targets, inputs)    
    result = tversky + _lambda_ * focal
    return result

def total_loss(y_true, y_pred):
    sumval = hybrid_loss(y_true, y_pred)
    return (1/3)*sumval

# %%
opt_adam = optimizers.Adam()

model = FullModel()
model.compile(optimizer = opt_adam, loss = hybrid_loss, metrics = [tf.keras.metrics.MeanIoU(num_classes=2)])
model.summary()
# Out:
# (None, 256, 256, 3)
# Model: "SemanticSegModel"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# img0_input (InputLayer)         [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# img1_input (InputLayer)         [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# img2_input (InputLayer)         [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 256, 256, 8)  224         img0_input[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 256, 256, 8)  224         img1_input[0][0]
# __________________________________________________________________________________________________
# conv2d_95 (Conv2D)              (None, 256, 256, 8)  224         img2_input[0][0]
# __________________________________________________________________________________________________
# elu_54 (ELU)                    (None, 256, 256, 8)  0           conv2d_57[0][0]
# __________________________________________________________________________________________________
# elu_72 (ELU)                    (None, 256, 256, 8)  0           conv2d_76[0][0]
# __________________________________________________________________________________________________
# elu_90 (ELU)                    (None, 256, 256, 8)  0           conv2d_95[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 256, 256, 8)  32          elu_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_75 (BatchNo (None, 256, 256, 8)  32          elu_72[0][0]
# __________________________________________________________________________________________________
# batch_normalization_93 (BatchNo (None, 256, 256, 8)  32          elu_90[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 256, 256, 8)  584         batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 256, 256, 8)  584         batch_normalization_75[0][0]
# __________________________________________________________________________________________________
# conv2d_96 (Conv2D)              (None, 256, 256, 8)  584         batch_normalization_93[0][0]
# __________________________________________________________________________________________________
# elu_55 (ELU)                    (None, 256, 256, 8)  0           conv2d_58[0][0]
# __________________________________________________________________________________________________
# elu_73 (ELU)                    (None, 256, 256, 8)  0           conv2d_77[0][0]
# __________________________________________________________________________________________________
# elu_91 (ELU)                    (None, 256, 256, 8)  0           conv2d_96[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 256, 256, 8)  32          elu_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_76 (BatchNo (None, 256, 256, 8)  32          elu_73[0][0]
# __________________________________________________________________________________________________
# batch_normalization_94 (BatchNo (None, 256, 256, 8)  32          elu_91[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_12 (MaxPooling2D) (None, 128, 128, 8)  0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_16 (MaxPooling2D) (None, 128, 128, 8)  0           batch_normalization_76[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_20 (MaxPooling2D) (None, 128, 128, 8)  0           batch_normalization_94[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 128, 128, 16) 1168        max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, 128, 128, 16) 1168        max_pooling2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_97 (Conv2D)              (None, 128, 128, 16) 1168        max_pooling2d_20[0][0]
# __________________________________________________________________________________________________
# elu_56 (ELU)                    (None, 128, 128, 16) 0           conv2d_59[0][0]
# __________________________________________________________________________________________________
# elu_74 (ELU)                    (None, 128, 128, 16) 0           conv2d_78[0][0]
# __________________________________________________________________________________________________
# elu_92 (ELU)                    (None, 128, 128, 16) 0           conv2d_97[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 128, 128, 16) 64          elu_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_77 (BatchNo (None, 128, 128, 16) 64          elu_74[0][0]
# __________________________________________________________________________________________________
# batch_normalization_95 (BatchNo (None, 128, 128, 16) 64          elu_92[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 128, 128, 16) 2320        batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, 128, 128, 16) 2320        batch_normalization_77[0][0]
# __________________________________________________________________________________________________
# conv2d_98 (Conv2D)              (None, 128, 128, 16) 2320        batch_normalization_95[0][0]
# __________________________________________________________________________________________________
# elu_57 (ELU)                    (None, 128, 128, 16) 0           conv2d_60[0][0]
# __________________________________________________________________________________________________
# elu_75 (ELU)                    (None, 128, 128, 16) 0           conv2d_79[0][0]
# __________________________________________________________________________________________________
# elu_93 (ELU)                    (None, 128, 128, 16) 0           conv2d_98[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 128, 128, 16) 64          elu_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_78 (BatchNo (None, 128, 128, 16) 64          elu_75[0][0]
# __________________________________________________________________________________________________
# batch_normalization_96 (BatchNo (None, 128, 128, 16) 64          elu_93[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_13 (MaxPooling2D) (None, 64, 64, 16)   0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_17 (MaxPooling2D) (None, 64, 64, 16)   0           batch_normalization_78[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_21 (MaxPooling2D) (None, 64, 64, 16)   0           batch_normalization_96[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 64, 64, 32)   4640        max_pooling2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, 64, 64, 32)   4640        max_pooling2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_99 (Conv2D)              (None, 64, 64, 32)   4640        max_pooling2d_21[0][0]
# __________________________________________________________________________________________________
# elu_58 (ELU)                    (None, 64, 64, 32)   0           conv2d_61[0][0]
# __________________________________________________________________________________________________
# elu_76 (ELU)                    (None, 64, 64, 32)   0           conv2d_80[0][0]
# __________________________________________________________________________________________________
# elu_94 (ELU)                    (None, 64, 64, 32)   0           conv2d_99[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 64, 64, 32)   128         elu_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_79 (BatchNo (None, 64, 64, 32)   128         elu_76[0][0]
# __________________________________________________________________________________________________
# batch_normalization_97 (BatchNo (None, 64, 64, 32)   128         elu_94[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 64, 64, 16)   528         batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, 64, 64, 16)   528         batch_normalization_79[0][0]
# __________________________________________________________________________________________________
# conv2d_100 (Conv2D)             (None, 64, 64, 16)   528         batch_normalization_97[0][0]
# __________________________________________________________________________________________________
# elu_59 (ELU)                    (None, 64, 64, 16)   0           conv2d_62[0][0]
# __________________________________________________________________________________________________
# elu_77 (ELU)                    (None, 64, 64, 16)   0           conv2d_81[0][0]
# __________________________________________________________________________________________________
# elu_95 (ELU)                    (None, 64, 64, 16)   0           conv2d_100[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 64, 64, 16)   64          elu_59[0][0]
# __________________________________________________________________________________________________
# batch_normalization_80 (BatchNo (None, 64, 64, 16)   64          elu_77[0][0]
# __________________________________________________________________________________________________
# batch_normalization_98 (BatchNo (None, 64, 64, 16)   64          elu_95[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 64, 64, 32)   4640        batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, 64, 64, 32)   4640        batch_normalization_80[0][0]
# __________________________________________________________________________________________________
# conv2d_101 (Conv2D)             (None, 64, 64, 32)   4640        batch_normalization_98[0][0]
# __________________________________________________________________________________________________
# elu_60 (ELU)                    (None, 64, 64, 32)   0           conv2d_63[0][0]
# __________________________________________________________________________________________________
# elu_78 (ELU)                    (None, 64, 64, 32)   0           conv2d_82[0][0]
# __________________________________________________________________________________________________
# elu_96 (ELU)                    (None, 64, 64, 32)   0           conv2d_101[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 64, 64, 32)   128         elu_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_81 (BatchNo (None, 64, 64, 32)   128         elu_78[0][0]
# __________________________________________________________________________________________________
# batch_normalization_99 (BatchNo (None, 64, 64, 32)   128         elu_96[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_14 (MaxPooling2D) (None, 32, 32, 32)   0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_18 (MaxPooling2D) (None, 32, 32, 32)   0           batch_normalization_81[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_22 (MaxPooling2D) (None, 32, 32, 32)   0           batch_normalization_99[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 32, 32, 48)   13872       max_pooling2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, 32, 32, 48)   13872       max_pooling2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_102 (Conv2D)             (None, 32, 32, 48)   13872       max_pooling2d_22[0][0]
# __________________________________________________________________________________________________
# elu_61 (ELU)                    (None, 32, 32, 48)   0           conv2d_64[0][0]
# __________________________________________________________________________________________________
# elu_79 (ELU)                    (None, 32, 32, 48)   0           conv2d_83[0][0]
# __________________________________________________________________________________________________
# elu_97 (ELU)                    (None, 32, 32, 48)   0           conv2d_102[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 32, 32, 48)   192         elu_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_82 (BatchNo (None, 32, 32, 48)   192         elu_79[0][0]
# __________________________________________________________________________________________________
# batch_normalization_100 (BatchN (None, 32, 32, 48)   192         elu_97[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 32, 32, 32)   1568        batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, 32, 32, 32)   1568        batch_normalization_82[0][0]
# __________________________________________________________________________________________________
# conv2d_103 (Conv2D)             (None, 32, 32, 32)   1568        batch_normalization_100[0][0]
# __________________________________________________________________________________________________
# elu_62 (ELU)                    (None, 32, 32, 32)   0           conv2d_65[0][0]
# __________________________________________________________________________________________________
# elu_80 (ELU)                    (None, 32, 32, 32)   0           conv2d_84[0][0]
# __________________________________________________________________________________________________
# elu_98 (ELU)                    (None, 32, 32, 32)   0           conv2d_103[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 32, 32, 32)   128         elu_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_83 (BatchNo (None, 32, 32, 32)   128         elu_80[0][0]
# __________________________________________________________________________________________________
# batch_normalization_101 (BatchN (None, 32, 32, 32)   128         elu_98[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 32, 32, 48)   13872       batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 32, 32, 48)   13872       batch_normalization_83[0][0]
# __________________________________________________________________________________________________
# conv2d_104 (Conv2D)             (None, 32, 32, 48)   13872       batch_normalization_101[0][0]
# __________________________________________________________________________________________________
# elu_63 (ELU)                    (None, 32, 32, 48)   0           conv2d_66[0][0]
# __________________________________________________________________________________________________
# elu_81 (ELU)                    (None, 32, 32, 48)   0           conv2d_85[0][0]
# __________________________________________________________________________________________________
# elu_99 (ELU)                    (None, 32, 32, 48)   0           conv2d_104[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 32, 32, 48)   192         elu_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_84 (BatchNo (None, 32, 32, 48)   192         elu_81[0][0]
# __________________________________________________________________________________________________
# batch_normalization_102 (BatchN (None, 32, 32, 48)   192         elu_99[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_15 (MaxPooling2D) (None, 16, 16, 48)   0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_19 (MaxPooling2D) (None, 16, 16, 48)   0           batch_normalization_84[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_23 (MaxPooling2D) (None, 16, 16, 48)   0           batch_normalization_102[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 16, 16, 48)   20784       max_pooling2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, 16, 16, 48)   20784       max_pooling2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_105 (Conv2D)             (None, 16, 16, 48)   20784       max_pooling2d_23[0][0]
# __________________________________________________________________________________________________
# elu_64 (ELU)                    (None, 16, 16, 48)   0           conv2d_67[0][0]
# __________________________________________________________________________________________________
# elu_82 (ELU)                    (None, 16, 16, 48)   0           conv2d_86[0][0]
# __________________________________________________________________________________________________
# elu_100 (ELU)                   (None, 16, 16, 48)   0           conv2d_105[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 16, 16, 48)   192         elu_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_85 (BatchNo (None, 16, 16, 48)   192         elu_82[0][0]
# __________________________________________________________________________________________________
# batch_normalization_103 (BatchN (None, 16, 16, 48)   192         elu_100[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_12 (UpSampling2D) (None, 32, 32, 48)   0           batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_16 (UpSampling2D) (None, 32, 32, 48)   0           batch_normalization_85[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_20 (UpSampling2D) (None, 32, 32, 48)   0           batch_normalization_103[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 32, 32, 96)   0           batch_normalization_66[0][0]
#                                                                  up_sampling2d_12[0][0]
# __________________________________________________________________________________________________
# concatenate_18 (Concatenate)    (None, 32, 32, 96)   0           batch_normalization_84[0][0]
#                                                                  up_sampling2d_16[0][0]
# __________________________________________________________________________________________________
# concatenate_22 (Concatenate)    (None, 32, 32, 96)   0           batch_normalization_102[0][0]
#                                                                  up_sampling2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 32, 32, 32)   27680       concatenate_14[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, 32, 32, 32)   27680       concatenate_18[0][0]
# __________________________________________________________________________________________________
# conv2d_106 (Conv2D)             (None, 32, 32, 32)   27680       concatenate_22[0][0]
# __________________________________________________________________________________________________
# elu_65 (ELU)                    (None, 32, 32, 32)   0           conv2d_68[0][0]
# __________________________________________________________________________________________________
# elu_83 (ELU)                    (None, 32, 32, 32)   0           conv2d_87[0][0]
# __________________________________________________________________________________________________
# elu_101 (ELU)                   (None, 32, 32, 32)   0           conv2d_106[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 32, 32, 32)   128         elu_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_86 (BatchNo (None, 32, 32, 32)   128         elu_83[0][0]
# __________________________________________________________________________________________________
# batch_normalization_104 (BatchN (None, 32, 32, 32)   128         elu_101[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 32, 32, 32)   9248        batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, 32, 32, 32)   9248        batch_normalization_86[0][0]
# __________________________________________________________________________________________________
# conv2d_107 (Conv2D)             (None, 32, 32, 32)   9248        batch_normalization_104[0][0]
# __________________________________________________________________________________________________
# elu_66 (ELU)                    (None, 32, 32, 32)   0           conv2d_69[0][0]
# __________________________________________________________________________________________________
# elu_84 (ELU)                    (None, 32, 32, 32)   0           conv2d_88[0][0]
# __________________________________________________________________________________________________
# elu_102 (ELU)                   (None, 32, 32, 32)   0           conv2d_107[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 32, 32, 32)   128         elu_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_87 (BatchNo (None, 32, 32, 32)   128         elu_84[0][0]
# __________________________________________________________________________________________________
# batch_normalization_105 (BatchN (None, 32, 32, 32)   128         elu_102[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_13 (UpSampling2D) (None, 64, 64, 32)   0           batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_17 (UpSampling2D) (None, 64, 64, 32)   0           batch_normalization_87[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_21 (UpSampling2D) (None, 64, 64, 32)   0           batch_normalization_105[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 64, 64, 64)   0           batch_normalization_63[0][0]
#                                                                  up_sampling2d_13[0][0]
# __________________________________________________________________________________________________
# concatenate_19 (Concatenate)    (None, 64, 64, 64)   0           batch_normalization_81[0][0]
#                                                                  up_sampling2d_17[0][0]
# __________________________________________________________________________________________________
# concatenate_23 (Concatenate)    (None, 64, 64, 64)   0           batch_normalization_99[0][0]
#                                                                  up_sampling2d_21[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 64, 64, 16)   9232        concatenate_15[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, 64, 64, 16)   9232        concatenate_19[0][0]
# __________________________________________________________________________________________________
# conv2d_108 (Conv2D)             (None, 64, 64, 16)   9232        concatenate_23[0][0]
# __________________________________________________________________________________________________
# elu_67 (ELU)                    (None, 64, 64, 16)   0           conv2d_70[0][0]
# __________________________________________________________________________________________________
# elu_85 (ELU)                    (None, 64, 64, 16)   0           conv2d_89[0][0]
# __________________________________________________________________________________________________
# elu_103 (ELU)                   (None, 64, 64, 16)   0           conv2d_108[0][0]
# __________________________________________________________________________________________________
# batch_normalization_70 (BatchNo (None, 64, 64, 16)   64          elu_67[0][0]
# __________________________________________________________________________________________________
# batch_normalization_88 (BatchNo (None, 64, 64, 16)   64          elu_85[0][0]
# __________________________________________________________________________________________________
# batch_normalization_106 (BatchN (None, 64, 64, 16)   64          elu_103[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 64, 64, 16)   2320        batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, 64, 64, 16)   2320        batch_normalization_88[0][0]
# __________________________________________________________________________________________________
# conv2d_109 (Conv2D)             (None, 64, 64, 16)   2320        batch_normalization_106[0][0]
# __________________________________________________________________________________________________
# elu_68 (ELU)                    (None, 64, 64, 16)   0           conv2d_71[0][0]
# __________________________________________________________________________________________________
# elu_86 (ELU)                    (None, 64, 64, 16)   0           conv2d_90[0][0]
# __________________________________________________________________________________________________
# elu_104 (ELU)                   (None, 64, 64, 16)   0           conv2d_109[0][0]
# __________________________________________________________________________________________________
# batch_normalization_71 (BatchNo (None, 64, 64, 16)   64          elu_68[0][0]
# __________________________________________________________________________________________________
# batch_normalization_89 (BatchNo (None, 64, 64, 16)   64          elu_86[0][0]
# __________________________________________________________________________________________________
# batch_normalization_107 (BatchN (None, 64, 64, 16)   64          elu_104[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_14 (UpSampling2D) (None, 128, 128, 16) 0           batch_normalization_71[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_18 (UpSampling2D) (None, 128, 128, 16) 0           batch_normalization_89[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_22 (UpSampling2D) (None, 128, 128, 16) 0           batch_normalization_107[0][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, 128, 128, 32) 0           batch_normalization_60[0][0]
#                                                                  up_sampling2d_14[0][0]
# __________________________________________________________________________________________________
# concatenate_20 (Concatenate)    (None, 128, 128, 32) 0           batch_normalization_78[0][0]
#                                                                  up_sampling2d_18[0][0]
# __________________________________________________________________________________________________
# concatenate_24 (Concatenate)    (None, 128, 128, 32) 0           batch_normalization_96[0][0]
#                                                                  up_sampling2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_72 (Conv2D)              (None, 128, 128, 8)  2312        concatenate_16[0][0]
# __________________________________________________________________________________________________
# conv2d_91 (Conv2D)              (None, 128, 128, 8)  2312        concatenate_20[0][0]
# __________________________________________________________________________________________________
# conv2d_110 (Conv2D)             (None, 128, 128, 8)  2312        concatenate_24[0][0]
# __________________________________________________________________________________________________
# elu_69 (ELU)                    (None, 128, 128, 8)  0           conv2d_72[0][0]
# __________________________________________________________________________________________________
# elu_87 (ELU)                    (None, 128, 128, 8)  0           conv2d_91[0][0]
# __________________________________________________________________________________________________
# elu_105 (ELU)                   (None, 128, 128, 8)  0           conv2d_110[0][0]
# __________________________________________________________________________________________________
# batch_normalization_72 (BatchNo (None, 128, 128, 8)  32          elu_69[0][0]
# __________________________________________________________________________________________________
# batch_normalization_90 (BatchNo (None, 128, 128, 8)  32          elu_87[0][0]
# __________________________________________________________________________________________________
# batch_normalization_108 (BatchN (None, 128, 128, 8)  32          elu_105[0][0]
# __________________________________________________________________________________________________
# conv2d_73 (Conv2D)              (None, 128, 128, 8)  584         batch_normalization_72[0][0]
# __________________________________________________________________________________________________
# conv2d_92 (Conv2D)              (None, 128, 128, 8)  584         batch_normalization_90[0][0]
# __________________________________________________________________________________________________
# conv2d_111 (Conv2D)             (None, 128, 128, 8)  584         batch_normalization_108[0][0]
# __________________________________________________________________________________________________
# elu_70 (ELU)                    (None, 128, 128, 8)  0           conv2d_73[0][0]
# __________________________________________________________________________________________________
# elu_88 (ELU)                    (None, 128, 128, 8)  0           conv2d_92[0][0]
# __________________________________________________________________________________________________
# elu_106 (ELU)                   (None, 128, 128, 8)  0           conv2d_111[0][0]
# __________________________________________________________________________________________________
# batch_normalization_73 (BatchNo (None, 128, 128, 8)  32          elu_70[0][0]
# __________________________________________________________________________________________________
# batch_normalization_91 (BatchNo (None, 128, 128, 8)  32          elu_88[0][0]
# __________________________________________________________________________________________________
# batch_normalization_109 (BatchN (None, 128, 128, 8)  32          elu_106[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_15 (UpSampling2D) (None, 256, 256, 8)  0           batch_normalization_73[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_19 (UpSampling2D) (None, 256, 256, 8)  0           batch_normalization_91[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_23 (UpSampling2D) (None, 256, 256, 8)  0           batch_normalization_109[0][0]
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, 256, 256, 16) 0           batch_normalization_58[0][0]
#                                                                  up_sampling2d_15[0][0]
# __________________________________________________________________________________________________
# concatenate_21 (Concatenate)    (None, 256, 256, 16) 0           batch_normalization_76[0][0]
#                                                                  up_sampling2d_19[0][0]
# __________________________________________________________________________________________________
# concatenate_25 (Concatenate)    (None, 256, 256, 16) 0           batch_normalization_94[0][0]
#                                                                  up_sampling2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_74 (Conv2D)              (None, 256, 256, 4)  68          concatenate_17[0][0]
# __________________________________________________________________________________________________
# conv2d_93 (Conv2D)              (None, 256, 256, 4)  68          concatenate_21[0][0]
# __________________________________________________________________________________________________
# conv2d_112 (Conv2D)             (None, 256, 256, 4)  68          concatenate_25[0][0]
# __________________________________________________________________________________________________
# elu_71 (ELU)                    (None, 256, 256, 4)  0           conv2d_74[0][0]
# __________________________________________________________________________________________________
# elu_89 (ELU)                    (None, 256, 256, 4)  0           conv2d_93[0][0]
# __________________________________________________________________________________________________
# elu_107 (ELU)                   (None, 256, 256, 4)  0           conv2d_112[0][0]
# __________________________________________________________________________________________________
# batch_normalization_74 (BatchNo (None, 256, 256, 4)  16          elu_71[0][0]
# __________________________________________________________________________________________________
# batch_normalization_92 (BatchNo (None, 256, 256, 4)  16          elu_89[0][0]
# __________________________________________________________________________________________________
# batch_normalization_110 (BatchN (None, 256, 256, 4)  16          elu_107[0][0]
# __________________________________________________________________________________________________
# boundary_input (InputLayer)     [(None, 256, 256, 1) 0
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 256, 256, 1)  5           batch_normalization_74[0][0]
# __________________________________________________________________________________________________
# conv2d_94 (Conv2D)              (None, 256, 256, 1)  5           batch_normalization_92[0][0]
# __________________________________________________________________________________________________
# conv2d_113 (Conv2D)             (None, 256, 256, 1)  5           batch_normalization_110[0][0]
# __________________________________________________________________________________________________
# multiply_6 (Multiply)           (None, 256, 256, 1)  0           conv2d_75[0][0]
#                                                                  boundary_input[0][0]
# __________________________________________________________________________________________________
# multiply_7 (Multiply)           (None, 256, 256, 1)  0           conv2d_94[0][0]
#                                                                  boundary_input[0][0]
# __________________________________________________________________________________________________
# multiply_8 (Multiply)           (None, 256, 256, 1)  0           conv2d_113[0][0]
#                                                                  boundary_input[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_3 (TFOpLambda)   (None, 1, 256, 256,  0           multiply_6[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_4 (TFOpLambda)   (None, 1, 256, 256,  0           multiply_7[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_5 (TFOpLambda)   (None, 1, 256, 256,  0           multiply_8[0][0]
# __________________________________________________________________________________________________
# concatenate_26 (Concatenate)    (None, 3, 256, 256,  0           tf.expand_dims_3[0][0]
#                                                                  tf.expand_dims_4[0][0]
#                                                                  tf.expand_dims_5[0][0]
# __________________________________________________________________________________________________
# conv_lst_m2d_3 (ConvLSTM2D)     (None, 3, 256, 256,  27264       concatenate_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_111 (BatchN (None, 3, 256, 256,  64          conv_lst_m2d_3[0][0]
# __________________________________________________________________________________________________
# conv_lst_m2d_4 (ConvLSTM2D)     (None, 3, 256, 256,  18496       batch_normalization_111[0][0]
# __________________________________________________________________________________________________
# batch_normalization_112 (BatchN (None, 3, 256, 256,  64          conv_lst_m2d_4[0][0]
# __________________________________________________________________________________________________
# conv_lst_m2d_5 (ConvLSTM2D)     (None, 3, 256, 256,  2112        batch_normalization_112[0][0]
# __________________________________________________________________________________________________
# batch_normalization_113 (BatchN (None, 3, 256, 256,  64          conv_lst_m2d_5[0][0]
# __________________________________________________________________________________________________
# conv3d_1 (Conv3D)               (None, 3, 256, 256,  433         batch_normalization_113[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_3 (Sli (None, 256, 256, 1)  0           conv3d_1[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_4 (Sli (None, 256, 256, 1)  0           conv3d_1[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_5 (Sli (None, 256, 256, 1)  0           conv3d_1[0][0]
# __________________________________________________________________________________________________
# multiply_9 (Multiply)           (None, 256, 256, 1)  0           boundary_input[0][0]
#                                                                  tf.__operators__.getitem_3[0][0]
# __________________________________________________________________________________________________
# multiply_10 (Multiply)          (None, 256, 256, 1)  0           boundary_input[0][0]
#                                                                  tf.__operators__.getitem_4[0][0]
# __________________________________________________________________________________________________
# multiply_11 (Multiply)          (None, 256, 256, 1)  0           boundary_input[0][0]
#                                                                  tf.__operators__.getitem_5[0][0]
# __________________________________________________________________________________________________
# concatenate_27 (Concatenate)    (None, 256, 256, 3)  0           multiply_9[0][0]
#                                                                  multiply_10[0][0]
#                                                                  multiply_11[0][0]
# ==================================================================================================
# Total params: 400,484
# Trainable params: 397,868
# Non-trainable params: 2,616
# __________________________________________________________________________________________________

# %%
train_steps = len(image0_train_generator)
val_steps = len(image0_val_generator)

history = model.fit(train_generator, validation_data=val_generator, 
                    steps_per_epoch=train_steps, validation_steps=val_steps, 
                    epochs = 5, verbose=1, callbacks=[checkpoint, lr_callback])
# Out:
# Epoch 1/5
# 308/308 [==============================] - 233s 729ms/step - loss: 1.6545 - mean_io_u_1: 0.4800 - val_loss: 1.5427 - val_mean_io_u_1: 0.4832
#
# Epoch 00001: val_loss improved from inf to 1.54270, saving model to model.h5
# Epoch 2/5
# 308/308 [==============================] - 45s 146ms/step - loss: 1.4991 - mean_io_u_1: 0.4792 - val_loss: 1.4979 - val_mean_io_u_1: 0.4834
#
# Epoch 00002: val_loss improved from 1.54270 to 1.49791, saving model to model.h5
# Epoch 3/5
# 308/308 [==============================] - 46s 150ms/step - loss: 1.3956 - mean_io_u_1: 0.4800 - val_loss: 1.3470 - val_mean_io_u_1: 0.4832
#
# Epoch 00003: val_loss improved from 1.49791 to 1.34695, saving model to model.h5
# Epoch 4/5
# 308/308 [==============================] - 50s 163ms/step - loss: 1.3394 - mean_io_u_1: 0.4791 - val_loss: 1.3186 - val_mean_io_u_1: 0.4843
#
# Epoch 00004: val_loss improved from 1.34695 to 1.31865, saving model to model.h5
# Epoch 5/5
# 308/308 [==============================] - 53s 172ms/step - loss: 1.3051 - mean_io_u_1: 0.4802 - val_loss: 1.2694 - val_mean_io_u_1: 0.4834
#
# Epoch 00005: val_loss improved from 1.31865 to 1.26939, saving model to model.h5

# %%
plt.figure()
plt.plot(history.history['mean_io_u_1'], label = 'Train IOU')
plt.plot(history.history['val_mean_io_u_1'], label = 'Val IOU')
plt.title('Mean IOU')
plt.legend()

plt.figure()
plt.plot(history.history['loss'], label = 'Train loss')
plt.plot(history.history['val_loss'], label = 'Val loss')
plt.title('loss')
plt.legend()

# %%
max_show = 1
test_iter = iter(test_generator)
for i in range(max_show):
    images, masks = next(test_iter)
    print(images[2].shape)
    print(masks.shape)
    pred_masks = model.predict(images)[:,:,:,2]
    fig, ax = plt.subplots(1, 3, figsize=(15, 6))
    for a in ax:
        a.axis('off')

    ax[0].imshow(images[2][i])
    ax[0].set_title('Original')
    ax[1].imshow(pred_masks[i])
    ax[1].set_title('Prediction')
    
    ax[2].imshow(masks[i,:,:,2])
    ax[2].set_title('Ground truth')
    #plt.savefig(f"pred_{i}.jpg", dpi=150)
    plt.show()
# Out:
# (1, 256, 256, 3)
# (1, 256, 256, 3)
