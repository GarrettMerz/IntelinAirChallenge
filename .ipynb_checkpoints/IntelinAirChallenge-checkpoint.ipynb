# %% [markdown]
# Welcome to my attempt at the Intelinair CVPR challenge! The goal is to do semantic segmentation of the images provided. I'm going to attempt to recreate a slimmed-down version of the model in the paper.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import tensorflow as tf
import tensorflow.keras
from tensorflow.keras import optimizers
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten 
from tensorflow.keras.layers import Conv2D, AveragePooling2D, MaxPooling2D, GlobalMaxPooling2D, ELU, Conv3D, ConvLSTM2D 
from tensorflow.keras.layers import UpSampling2D, Concatenate, Multiply
from tensorflow.keras.preprocessing import image
from keras_preprocessing.image import ImageDataGenerator
from tensorflow.python.keras.utils import layer_utils
from tensorflow.python.keras.utils.data_utils import get_file
from tensorflow.keras.applications.imagenet_utils import preprocess_input
from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.model_selection import train_test_split
import tensorflow.keras.backend as K
import random
import cv2
import sys

# %%
input_img0_names = []
input_img1_names = []
input_img2_names = []
boundary_mask_names = []
nutrient_mask_names = []

HEIGHT = 256
WIDTH = 256
CHANNELS = 3
BATCH_SIZE = 1
src_dir = '/home/garrett/Documents/IntelinAirData/Longitudinal_Nutrient_Deficiency'

for i in range(1,387):
    filestring = str(i).zfill(3)
    input_img0_names.append(os.path.join(src_dir, f'field_{filestring}/image_i0.png'))
    input_img1_names.append(os.path.join(src_dir, f'field_{filestring}/image_i1.png'))
    input_img2_names.append(os.path.join(src_dir, f'field_{filestring}/image_i2.png'))
    boundary_mask_names.append(os.path.join(src_dir, f'field_{filestring}/bounday_mask.png'))
    nutrient_mask_names.append(os.path.join(src_dir, f'field_{filestring}/nutrient_mask_g0.png'))
    
df = pd.DataFrame({'image_0':input_img0_names , 'image_1':input_img1_names, 'image_2':input_img2_names, 
                   'boundary_mask':boundary_mask_names, 'nutrient_mask':nutrient_mask_names})
#df.reset_index(drop=True, inplace=True)
df.head(5)

XY_train,XY_valtest = train_test_split(df, train_size=0.8, random_state=0)
XY_val, XY_test = train_test_split(XY_valtest, train_size=0.5, random_state=0)
XY_train.reset_index(drop=True, inplace=True)
XY_val.reset_index(drop=True, inplace=True)
XY_test.reset_index(drop=True, inplace=True)
XY_train.head(5)
# Out:
#                                              image_0  \
# 0  /home/garrett/Documents/IntelinAirData/Longitu...
# 1  /home/garrett/Documents/IntelinAirData/Longitu...
# 2  /home/garrett/Documents/IntelinAirData/Longitu...
# 3  /home/garrett/Documents/IntelinAirData/Longitu...
# 4  /home/garrett/Documents/IntelinAirData/Longitu...
#
#                                              image_1  \
# 0  /home/garrett/Documents/IntelinAirData/Longitu...
# 1  /home/garrett/Documents/IntelinAirData/Longitu...
# 2  /home/garrett/Documents/IntelinAirData/Longitu...
# 3  /home/garrett/Documents/IntelinAirData/Longitu...
# 4  /home/garrett/Documents/IntelinAirData/Longitu...
#
#                                              image_2  \
# 0  /home/garrett/Documents/IntelinAirData/Longitu...
# 1  /home/garrett/Documents/IntelinAirData/Longitu...
# 2  /home/garrett/Documents/IntelinAirData/Longitu...
# 3  /home/garrett/Documents/IntelinAirData/Longitu...
# 4  /home/garrett/Documents/IntelinAirData/Longitu...
#
#                                        boundary_mask  \
# 0  /home/garrett/Documents/IntelinAirData/Longitu...
# 1  /home/garrett/Documents/IntelinAirData/Longitu...
# 2  /home/garrett/Documents/IntelinAirData/Longitu...
# 3  /home/garrett/Documents/IntelinAirData/Longitu...
# 4  /home/garrett/Documents/IntelinAirData/Longitu...
#
#                                        nutrient_mask
# 0  /home/garrett/Documents/IntelinAirData/Longitu...
# 1  /home/garrett/Documents/IntelinAirData/Longitu...
# 2  /home/garrett/Documents/IntelinAirData/Longitu...
# 3  /home/garrett/Documents/IntelinAirData/Longitu...
# 4  /home/garrett/Documents/IntelinAirData/Longitu...

# %%
index = random.randint(0, len(XY_train)-1)
img = cv2.imread(XY_train.loc[index].at["image_0"])
mask = cv2.imread(XY_train.loc[index].at["nutrient_mask"])
bdymask = cv2.imread(XY_train.loc[index].at["boundary_mask"])

plt.figure(figsize=(20, 6))
plt.subplot(131)
plt.imshow(img)
plt.title('Original')
plt.axis('off')

plt.subplot(132)
plt.imshow(mask)
plt.title('Mask')
plt.axis('off')

plt.subplot(133)
plt.imshow(bdymask)
plt.title('Boundary Mask')
plt.axis('off')
# Out:
# (-0.5, 1063.5, 1107.5, -0.5)

# %%
def myGenerator(generator1,generator2,generator3,boundgenerator,outgenerator):
        while True:
            for x0,x1,x2,bound,y1 in zip(generator1,generator2,generator3,boundgenerator,outgenerator):
                #print(y1[:,:,:,2].shape)
                yield ([x0,x1,x2,bound[:,:,:,2]], y1)

# %%
image0_train_datagen = ImageDataGenerator(rescale=1./255.)
image1_train_datagen = ImageDataGenerator(rescale=1./255.)
image2_train_datagen = ImageDataGenerator(rescale=1./255.)
mask_train_datagen = ImageDataGenerator(rescale=1./255.)
boundary_train_datagen = ImageDataGenerator(rescale=1./255.)

image0_val_datagen = ImageDataGenerator(rescale=1./255.)
image1_val_datagen = ImageDataGenerator(rescale=1./255.)
image2_val_datagen = ImageDataGenerator(rescale=1./255.)
mask_val_datagen = ImageDataGenerator(rescale=1./255.)
boundary_val_datagen = ImageDataGenerator(rescale=1./255.)

image0_test_datagen = ImageDataGenerator(rescale=1./255.)
image1_test_datagen = ImageDataGenerator(rescale=1./255.)
image2_test_datagen = ImageDataGenerator(rescale=1./255.)
mask_test_datagen = ImageDataGenerator(rescale=1./255.)
boundary_test_datagen = ImageDataGenerator(rescale=1./255.)

# %%
seed = 1

image0_train_generator = image0_train_datagen.flow_from_dataframe(
    dataframe=XY_train,
    x_col="image_0",
    class_mode=None,
    horizontal_flip=True,
    vertical_flip=True,
    target_size = (WIDTH, HEIGHT),
    batch_size = BATCH_SIZE,
    seed=seed)

image1_train_generator = image1_train_datagen.flow_from_dataframe(
    dataframe=XY_train,
    x_col="image_1",
    class_mode=None,
    horizontal_flip=True,
    vertical_flip=True,
    target_size = (WIDTH, HEIGHT),
    batch_size = BATCH_SIZE,
    seed=seed)

image2_train_generator = image2_train_datagen.flow_from_dataframe(
    dataframe=XY_train,
    x_col="image_2",
    class_mode=None,
    horizontal_flip=True,
    vertical_flip=True,
    target_size = (WIDTH, HEIGHT),
    batch_size = BATCH_SIZE,
    seed=seed)

mask_train_generator = mask_train_datagen.flow_from_dataframe(
    dataframe=XY_train,
    x_col="nutrient_mask",
    class_mode=None,
    horizontal_flip=True,
    vertical_flip=True,
    target_size = (WIDTH, HEIGHT),
    batch_size = BATCH_SIZE,
    seed=seed)

boundary_train_generator = boundary_train_datagen.flow_from_dataframe(
    dataframe=XY_train,
    x_col="boundary_mask",
    class_mode=None,
    horizontal_flip=True,
    vertical_flip=True,
    target_size = (WIDTH, HEIGHT),
    batch_size = BATCH_SIZE,
    seed=seed)

# combine generators into one which yields image and masks
train_generator = myGenerator(image0_train_generator, image1_train_generator,
                              image2_train_generator, boundary_train_generator, mask_train_generator)
# Out:
# Found 308 validated image filenames.
# Found 308 validated image filenames.
# Found 308 validated image filenames.
# Found 308 validated image filenames.
# Found 308 validated image filenames.

# %%
seed = 1

image0_val_generator = image0_val_datagen.flow_from_dataframe(
    dataframe=XY_val,
    x_col="image_0",
    class_mode=None,
    horizontal_flip=True,
    vertical_flip=True,
    target_size = (WIDTH, HEIGHT),
    batch_size = BATCH_SIZE,
    seed=seed)

image1_val_generator = image1_val_datagen.flow_from_dataframe(
    dataframe=XY_val,
    x_col="image_1",
    class_mode=None,
    horizontal_flip=True,
    vertical_flip=True,
    target_size = (WIDTH, HEIGHT),
    batch_size = BATCH_SIZE,
    seed=seed)

image2_val_generator = image2_val_datagen.flow_from_dataframe(
    dataframe=XY_val,
    x_col="image_2",
    class_mode=None,
    horizontal_flip=True,
    vertical_flip=True,
    target_size = (WIDTH, HEIGHT),
    batch_size = BATCH_SIZE,
    seed=seed)

mask_val_generator = mask_val_datagen.flow_from_dataframe(
    dataframe=XY_val,
    x_col="nutrient_mask",
    class_mode=None,
    horizontal_flip=True,
    vertical_flip=True,
    target_size = (WIDTH, HEIGHT),
    batch_size = BATCH_SIZE,
    seed=seed)


boundary_val_generator = boundary_val_datagen.flow_from_dataframe(
    dataframe=XY_val,
    x_col="boundary_mask",
    class_mode=None,
    horizontal_flip=True,
    vertical_flip=True,
    target_size = (WIDTH, HEIGHT),
    batch_size = BATCH_SIZE,
    seed=seed)

# combine generators into one which yields image and masks
val_generator = myGenerator(image0_val_generator, image1_val_generator,
                              image2_val_generator, boundary_val_generator, mask_val_generator)
# Out:
# Found 39 validated image filenames.
# Found 39 validated image filenames.
# Found 39 validated image filenames.
# Found 39 validated image filenames.
# Found 39 validated image filenames.

# %%
seed = 1

image0_test_generator = image0_test_datagen.flow_from_dataframe(
    dataframe=XY_test,
    x_col="image_0",
    class_mode=None,
    horizontal_flip=True,
    vertical_flip=True,
    target_size = (WIDTH, HEIGHT),
    batch_size = BATCH_SIZE,
    seed=seed)

image1_test_generator = image1_test_datagen.flow_from_dataframe(
    dataframe=XY_test,
    x_col="image_1",
    class_mode=None,
    horizontal_flip=True,
    vertical_flip=True,
    target_size = (WIDTH, HEIGHT),
    batch_size = BATCH_SIZE,
    seed=seed)

image2_test_generator = image2_test_datagen.flow_from_dataframe(
    dataframe=XY_test,
    x_col="image_2",
    class_mode=None,
    horizontal_flip=True,
    vertical_flip=True,
    target_size = (WIDTH, HEIGHT),
    batch_size = BATCH_SIZE,
    seed=seed)

mask_test_generator = mask_test_datagen.flow_from_dataframe(
    dataframe=XY_test,
    x_col="nutrient_mask",
    class_mode=None,
    horizontal_flip=True,
    vertical_flip=True,
    target_size = (WIDTH, HEIGHT),
    batch_size = BATCH_SIZE,
    seed=seed)


boundary_test_generator = boundary_test_datagen.flow_from_dataframe(
    dataframe=XY_test,
    x_col="boundary_mask",
    class_mode=None,
    horizontal_flip=True,
    vertical_flip=True,
    target_size = (WIDTH, HEIGHT),
    batch_size = BATCH_SIZE,
    seed=seed)

# combine generators into one which yields image and masks
test_generator = myGenerator(image0_test_generator, image1_test_generator,
                              image2_test_generator, boundary_test_generator, mask_test_generator)
# Out:
# Found 39 validated image filenames.
# Found 39 validated image filenames.
# Found 39 validated image filenames.
# Found 39 validated image filenames.
# Found 39 validated image filenames.

# %%
#Given that I'm training three U-Nets in parallel, I can only afford a few filters for each layer.

def UNet(image_input, boundary_input):

    ''' ~~~~~~~~~~~~~~~~~~~ ENCODING LAYERS ~~~~~~~~~~~~~~~~~~~ '''

    c1 = Conv2D(8, kernel_size=(3,3), kernel_initializer='he_normal', padding = 'same')(image_input)
    c1 = ELU()(c1)
    c1 = BatchNormalization()(c1)
    c1 = Conv2D(8, kernel_size=(3,3), kernel_initializer='he_normal', padding = 'same')(c1)
    c1 = ELU()(c1)
    c1 = BatchNormalization()(c1)
    
    p1 = MaxPooling2D((2,2))(c1)

    c2 = Conv2D(8*2, kernel_size=(3,3), kernel_initializer='he_normal', padding = 'same')(p1)
    c2 = ELU()(c2)
    c2 = BatchNormalization()(c2)
    c2 = Conv2D(8*2, kernel_size=(3,3), kernel_initializer='he_normal', padding = 'same')(c2)
    c2 = ELU()(c2)
    c2 = BatchNormalization()(c2)
    p2 = MaxPooling2D((2,2))(c2)
    

    c3 = Conv2D(8*4, kernel_size=(3,3), kernel_initializer='he_normal', padding = 'same')(p2)
    c3 = ELU()(c3)
    c3 = BatchNormalization()(c3)
    c3 = Conv2D(8*2, kernel_size=(1,1), kernel_initializer='he_normal', padding = 'same')(c3)
    c3 = ELU()(c3)
    c3 = BatchNormalization()(c3)
    c3 = Conv2D(8*4, kernel_size=(3,3), kernel_initializer='he_normal', padding = 'same')(c3)
    c3 = ELU()(c3)
    c3 = BatchNormalization()(c3)

    p3 = MaxPooling2D((2,2))(c3)

    c4 = Conv2D(8*6, kernel_size=(3,3), kernel_initializer='he_normal', padding = 'same')(p3)
    c4 = ELU()(c4)
    c4 = BatchNormalization()(c4)
    c4 = Conv2D(8*4, kernel_size=(1,1), kernel_initializer='he_normal', padding = 'same')(c4)
    c4 = ELU()(c4)
    c4 = BatchNormalization()(c4)
    c4 = Conv2D(8*6, kernel_size=(3,3), kernel_initializer='he_normal', padding = 'same')(c4)
    c4 = ELU()(c4)
    c4 = BatchNormalization()(c4)

    p4 = MaxPooling2D((2,2))(c4)

    c5 = Conv2D(8*6, kernel_size=(3,3), kernel_initializer='he_normal', padding = 'same')(p4)
    c5 = ELU()(c5)
    c5 = BatchNormalization()(c5)


    ''' ~~~~~~~~~~~~~~~~~~~ DECODING LAYERS ~~~~~~~~~~~~~~~~~~~ '''

    u1 = UpSampling2D((2,2))(c5)
    concat1 = Concatenate()([c4, u1])

    c6 = Conv2D(8*4, kernel_size=(3,3), kernel_initializer='he_normal', padding = 'same')(concat1)
    c6 = ELU()(c6)
    c6 = BatchNormalization()(c6)
    c6 = Conv2D(8*4, kernel_size=(3,3), kernel_initializer='he_normal', padding = 'same')(c6)
    c6 = ELU()(c6)
    c6 = BatchNormalization()(c6)


    u2 = UpSampling2D((2,2))(c6)
    concat2 = Concatenate()([c3, u2])

    c7 = Conv2D(8*2, kernel_size=(3,3), kernel_initializer='he_normal', padding = 'same')(concat2)
    c7 = ELU()(c7)
    c7 = BatchNormalization()(c7)
    c7 = Conv2D(8*2, kernel_size=(3,3), kernel_initializer='he_normal', padding = 'same')(c7)
    c7 = ELU()(c7)
    c7 = BatchNormalization()(c7)

    u3 = UpSampling2D((2,2))(c7)
    concat3 = Concatenate()([c2, u3])

    c8 = Conv2D(8, kernel_size=(3,3), kernel_initializer='he_normal', padding = 'same')(concat3)
    c8 = ELU()(c8)
    c8 = BatchNormalization()(c8)
    c8 = Conv2D(8, kernel_size=(3,3), kernel_initializer='he_normal', padding = 'same')(c8)
    c8 = ELU()(c8)
    c8 = BatchNormalization()(c8)

    u4 = UpSampling2D((2,2))(c8)
    concat4 = Concatenate()([c1, u4])

    c9 = Conv2D(4, kernel_size = (1,1), kernel_initializer='he_normal', padding = 'same')(concat4)
    c9 = ELU()(c9)
    c9 = BatchNormalization()(c9)

    mask_out = Conv2D(1, (1,1), kernel_initializer='he_normal', padding = 'same', activation = 'sigmoid')(c9)
    multmask = Multiply()([mask_out, boundary_input])
    
    return multmask

# %%
def ConvLSTM(movieIn, boundary_input):
    
    x = ConvLSTM2D(
    filters=16,
    kernel_size=(5, 5),
    padding="same",
    return_sequences=True,
    activation="elu",
    )(movieIn)

    x = BatchNormalization()(x)

    x = ConvLSTM2D(
    filters=16,
    kernel_size=(3, 3),
    padding="same",
    return_sequences=True,
    activation="elu",
    )(x)
    
    x = BatchNormalization()(x)
    
    x = ConvLSTM2D(
    filters=16,
    kernel_size=(1, 1),
    padding="same",
    return_sequences=True,
    activation="elu",
    )(x)
    
    x = BatchNormalization()(x)
    
    lastmask = Conv3D(
    filters=1,
    kernel_size=(3, 3, 3),
    activation="sigmoid",
    padding="same"
    )(x)
    
    P0 = Multiply()([boundary_input,lastmask[:,0,:,:,:]])
    P1 = Multiply()([boundary_input,lastmask[:,1,:,:,:]])
    P2 = Multiply()([boundary_input,lastmask[:,2,:,:,:]])
    
    outmask = Concatenate()([P0,P1,P2])
    
    return outmask

# %%
def LastOnlyModel():

    image0 = Input(shape=(HEIGHT, WIDTH, CHANNELS), name = 'img0_input')
    image1 = Input(shape=(HEIGHT, WIDTH, CHANNELS), name = 'img1_input')
    image2 = Input(shape=(HEIGHT, WIDTH, CHANNELS), name = 'img2_input')
    boundary = Input(shape=(HEIGHT, WIDTH, 1), name = 'boundary_input')
    outmask= UNet(image2, boundary)
    
    model = Model(inputs = [image0,image1,image2, boundary], outputs = outmask, name='SemanticSegModelOnlyLast')

    return model

# %%
def FullModel():

    image0 = Input(shape=(HEIGHT, WIDTH, CHANNELS), name = 'img0_input')
    image1 = Input(shape=(HEIGHT, WIDTH, CHANNELS), name = 'img1_input')
    image2 = Input(shape=(HEIGHT, WIDTH, CHANNELS), name = 'img2_input')
    boundary = Input(shape=(HEIGHT, WIDTH, 1), name = 'boundary_input')
    
    X1= UNet(image0, boundary)
    X2= UNet(image1, boundary)
    X3= UNet(image2, boundary)

    
    X1 = tf.keras.backend.expand_dims(X1,axis=1)
    X2 = tf.keras.backend.expand_dims(X2,axis=1)
    X3 = tf.keras.backend.expand_dims(X3,axis=1)
    movie=Concatenate(axis=1)([X1, X2, X3])

    
    outmask = ConvLSTM(movie, boundary)
    print(outmask.shape)                   
    model = Model(inputs = [image0,image1,image2, boundary], outputs = outmask, name='SemanticSegModel')

    
    return model

# %%
def lrfn(epoch):
    if epoch > 15:
        return 2e-6
    elif epoch > 25:
        return 1e-6
    return 1e-6

# %%
# Learning rate callback
lr_callback = tf.keras.callbacks.LearningRateScheduler(lambda step: lrfn(step))
# Model checkpoint, saves weights if val loss reduces
checkpoint = tf.keras.callbacks.ModelCheckpoint('model.h5', 'val_loss', save_best_only=True, save_weights_only=True, verbose=1)

# %%
def tversky_loss(targets, inputs, alpha=1, beta=1, numLabels=2):
    FIX THIS
    
    tversky = 0
    #flatten label and prediction tensors
    inputs = K.flatten(inputs)
    targets = K.flatten(targets)
        
    #True Positives, False Positives & False Negatives
    TP = K.sum((inputs * targets))
    FP = K.sum(((1-targets) * inputs))
    FN = K.sum((targets * (1-inputs)))
        
    tversky= (TP) / (TP + alpha*FP + beta*FN)  
    return (1 - tversky)

    
def focal_loss(targets, inputs, numLabels=2):

    FIX ALSO
    inputs = K.flatten(inputs)
    targets = K.flatten(targets)
    
    BCE = K.binary_crossentropy(targets, inputs)
    BCE_EXP = K.exp(-BCE)
    focal_loss = K.mean(K.pow((1-BCE_EXP), 2) * BCE)
    
    return focal_loss
            
def hybrid_loss(targets, inputs, _lambda_ = 1):
    tversky= tversky_loss(targets, inputs)
    focal=focal_loss(targets, inputs)    
    result = tversky + _lambda_ * focal
    return result

def total_loss(y_true, y_pred):
    sumval = hybrid_loss(y_true, y_pred)
    return (1/3)*sumval

# %%
opt_adam = optimizers.Adam()

model = FullModel()
model.compile(optimizer = opt_adam, loss = hybrid_loss, metrics = [tf.keras.metrics.MeanIoU(num_classes=2)])
model.summary()
# Out:
# (None, 256, 256, 3)
# Model: "SemanticSegModel"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# img0_input (InputLayer)         [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# img1_input (InputLayer)         [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# img2_input (InputLayer)         [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv2d_2261 (Conv2D)            (None, 256, 256, 8)  224         img0_input[0][0]
# __________________________________________________________________________________________________
# conv2d_2280 (Conv2D)            (None, 256, 256, 8)  224         img1_input[0][0]
# __________________________________________________________________________________________________
# conv2d_2299 (Conv2D)            (None, 256, 256, 8)  224         img2_input[0][0]
# __________________________________________________________________________________________________
# elu_2142 (ELU)                  (None, 256, 256, 8)  0           conv2d_2261[0][0]
# __________________________________________________________________________________________________
# elu_2160 (ELU)                  (None, 256, 256, 8)  0           conv2d_2280[0][0]
# __________________________________________________________________________________________________
# elu_2178 (ELU)                  (None, 256, 256, 8)  0           conv2d_2299[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2241 (Batch (None, 256, 256, 8)  32          elu_2142[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2259 (Batch (None, 256, 256, 8)  32          elu_2160[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2277 (Batch (None, 256, 256, 8)  32          elu_2178[0][0]
# __________________________________________________________________________________________________
# conv2d_2262 (Conv2D)            (None, 256, 256, 8)  584         batch_normalization_2241[0][0]
# __________________________________________________________________________________________________
# conv2d_2281 (Conv2D)            (None, 256, 256, 8)  584         batch_normalization_2259[0][0]
# __________________________________________________________________________________________________
# conv2d_2300 (Conv2D)            (None, 256, 256, 8)  584         batch_normalization_2277[0][0]
# __________________________________________________________________________________________________
# elu_2143 (ELU)                  (None, 256, 256, 8)  0           conv2d_2262[0][0]
# __________________________________________________________________________________________________
# elu_2161 (ELU)                  (None, 256, 256, 8)  0           conv2d_2281[0][0]
# __________________________________________________________________________________________________
# elu_2179 (ELU)                  (None, 256, 256, 8)  0           conv2d_2300[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2242 (Batch (None, 256, 256, 8)  32          elu_2143[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2260 (Batch (None, 256, 256, 8)  32          elu_2161[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2278 (Batch (None, 256, 256, 8)  32          elu_2179[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_476 (MaxPooling2D (None, 128, 128, 8)  0           batch_normalization_2242[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_480 (MaxPooling2D (None, 128, 128, 8)  0           batch_normalization_2260[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_484 (MaxPooling2D (None, 128, 128, 8)  0           batch_normalization_2278[0][0]
# __________________________________________________________________________________________________
# conv2d_2263 (Conv2D)            (None, 128, 128, 16) 1168        max_pooling2d_476[0][0]
# __________________________________________________________________________________________________
# conv2d_2282 (Conv2D)            (None, 128, 128, 16) 1168        max_pooling2d_480[0][0]
# __________________________________________________________________________________________________
# conv2d_2301 (Conv2D)            (None, 128, 128, 16) 1168        max_pooling2d_484[0][0]
# __________________________________________________________________________________________________
# elu_2144 (ELU)                  (None, 128, 128, 16) 0           conv2d_2263[0][0]
# __________________________________________________________________________________________________
# elu_2162 (ELU)                  (None, 128, 128, 16) 0           conv2d_2282[0][0]
# __________________________________________________________________________________________________
# elu_2180 (ELU)                  (None, 128, 128, 16) 0           conv2d_2301[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2243 (Batch (None, 128, 128, 16) 64          elu_2144[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2261 (Batch (None, 128, 128, 16) 64          elu_2162[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2279 (Batch (None, 128, 128, 16) 64          elu_2180[0][0]
# __________________________________________________________________________________________________
# conv2d_2264 (Conv2D)            (None, 128, 128, 16) 2320        batch_normalization_2243[0][0]
# __________________________________________________________________________________________________
# conv2d_2283 (Conv2D)            (None, 128, 128, 16) 2320        batch_normalization_2261[0][0]
# __________________________________________________________________________________________________
# conv2d_2302 (Conv2D)            (None, 128, 128, 16) 2320        batch_normalization_2279[0][0]
# __________________________________________________________________________________________________
# elu_2145 (ELU)                  (None, 128, 128, 16) 0           conv2d_2264[0][0]
# __________________________________________________________________________________________________
# elu_2163 (ELU)                  (None, 128, 128, 16) 0           conv2d_2283[0][0]
# __________________________________________________________________________________________________
# elu_2181 (ELU)                  (None, 128, 128, 16) 0           conv2d_2302[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2244 (Batch (None, 128, 128, 16) 64          elu_2145[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2262 (Batch (None, 128, 128, 16) 64          elu_2163[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2280 (Batch (None, 128, 128, 16) 64          elu_2181[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_477 (MaxPooling2D (None, 64, 64, 16)   0           batch_normalization_2244[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_481 (MaxPooling2D (None, 64, 64, 16)   0           batch_normalization_2262[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_485 (MaxPooling2D (None, 64, 64, 16)   0           batch_normalization_2280[0][0]
# __________________________________________________________________________________________________
# conv2d_2265 (Conv2D)            (None, 64, 64, 32)   4640        max_pooling2d_477[0][0]
# __________________________________________________________________________________________________
# conv2d_2284 (Conv2D)            (None, 64, 64, 32)   4640        max_pooling2d_481[0][0]
# __________________________________________________________________________________________________
# conv2d_2303 (Conv2D)            (None, 64, 64, 32)   4640        max_pooling2d_485[0][0]
# __________________________________________________________________________________________________
# elu_2146 (ELU)                  (None, 64, 64, 32)   0           conv2d_2265[0][0]
# __________________________________________________________________________________________________
# elu_2164 (ELU)                  (None, 64, 64, 32)   0           conv2d_2284[0][0]
# __________________________________________________________________________________________________
# elu_2182 (ELU)                  (None, 64, 64, 32)   0           conv2d_2303[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2245 (Batch (None, 64, 64, 32)   128         elu_2146[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2263 (Batch (None, 64, 64, 32)   128         elu_2164[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2281 (Batch (None, 64, 64, 32)   128         elu_2182[0][0]
# __________________________________________________________________________________________________
# conv2d_2266 (Conv2D)            (None, 64, 64, 16)   528         batch_normalization_2245[0][0]
# __________________________________________________________________________________________________
# conv2d_2285 (Conv2D)            (None, 64, 64, 16)   528         batch_normalization_2263[0][0]
# __________________________________________________________________________________________________
# conv2d_2304 (Conv2D)            (None, 64, 64, 16)   528         batch_normalization_2281[0][0]
# __________________________________________________________________________________________________
# elu_2147 (ELU)                  (None, 64, 64, 16)   0           conv2d_2266[0][0]
# __________________________________________________________________________________________________
# elu_2165 (ELU)                  (None, 64, 64, 16)   0           conv2d_2285[0][0]
# __________________________________________________________________________________________________
# elu_2183 (ELU)                  (None, 64, 64, 16)   0           conv2d_2304[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2246 (Batch (None, 64, 64, 16)   64          elu_2147[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2264 (Batch (None, 64, 64, 16)   64          elu_2165[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2282 (Batch (None, 64, 64, 16)   64          elu_2183[0][0]
# __________________________________________________________________________________________________
# conv2d_2267 (Conv2D)            (None, 64, 64, 32)   4640        batch_normalization_2246[0][0]
# __________________________________________________________________________________________________
# conv2d_2286 (Conv2D)            (None, 64, 64, 32)   4640        batch_normalization_2264[0][0]
# __________________________________________________________________________________________________
# conv2d_2305 (Conv2D)            (None, 64, 64, 32)   4640        batch_normalization_2282[0][0]
# __________________________________________________________________________________________________
# elu_2148 (ELU)                  (None, 64, 64, 32)   0           conv2d_2267[0][0]
# __________________________________________________________________________________________________
# elu_2166 (ELU)                  (None, 64, 64, 32)   0           conv2d_2286[0][0]
# __________________________________________________________________________________________________
# elu_2184 (ELU)                  (None, 64, 64, 32)   0           conv2d_2305[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2247 (Batch (None, 64, 64, 32)   128         elu_2148[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2265 (Batch (None, 64, 64, 32)   128         elu_2166[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2283 (Batch (None, 64, 64, 32)   128         elu_2184[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_478 (MaxPooling2D (None, 32, 32, 32)   0           batch_normalization_2247[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_482 (MaxPooling2D (None, 32, 32, 32)   0           batch_normalization_2265[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_486 (MaxPooling2D (None, 32, 32, 32)   0           batch_normalization_2283[0][0]
# __________________________________________________________________________________________________
# conv2d_2268 (Conv2D)            (None, 32, 32, 48)   13872       max_pooling2d_478[0][0]
# __________________________________________________________________________________________________
# conv2d_2287 (Conv2D)            (None, 32, 32, 48)   13872       max_pooling2d_482[0][0]
# __________________________________________________________________________________________________
# conv2d_2306 (Conv2D)            (None, 32, 32, 48)   13872       max_pooling2d_486[0][0]
# __________________________________________________________________________________________________
# elu_2149 (ELU)                  (None, 32, 32, 48)   0           conv2d_2268[0][0]
# __________________________________________________________________________________________________
# elu_2167 (ELU)                  (None, 32, 32, 48)   0           conv2d_2287[0][0]
# __________________________________________________________________________________________________
# elu_2185 (ELU)                  (None, 32, 32, 48)   0           conv2d_2306[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2248 (Batch (None, 32, 32, 48)   192         elu_2149[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2266 (Batch (None, 32, 32, 48)   192         elu_2167[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2284 (Batch (None, 32, 32, 48)   192         elu_2185[0][0]
# __________________________________________________________________________________________________
# conv2d_2269 (Conv2D)            (None, 32, 32, 32)   1568        batch_normalization_2248[0][0]
# __________________________________________________________________________________________________
# conv2d_2288 (Conv2D)            (None, 32, 32, 32)   1568        batch_normalization_2266[0][0]
# __________________________________________________________________________________________________
# conv2d_2307 (Conv2D)            (None, 32, 32, 32)   1568        batch_normalization_2284[0][0]
# __________________________________________________________________________________________________
# elu_2150 (ELU)                  (None, 32, 32, 32)   0           conv2d_2269[0][0]
# __________________________________________________________________________________________________
# elu_2168 (ELU)                  (None, 32, 32, 32)   0           conv2d_2288[0][0]
# __________________________________________________________________________________________________
# elu_2186 (ELU)                  (None, 32, 32, 32)   0           conv2d_2307[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2249 (Batch (None, 32, 32, 32)   128         elu_2150[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2267 (Batch (None, 32, 32, 32)   128         elu_2168[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2285 (Batch (None, 32, 32, 32)   128         elu_2186[0][0]
# __________________________________________________________________________________________________
# conv2d_2270 (Conv2D)            (None, 32, 32, 48)   13872       batch_normalization_2249[0][0]
# __________________________________________________________________________________________________
# conv2d_2289 (Conv2D)            (None, 32, 32, 48)   13872       batch_normalization_2267[0][0]
# __________________________________________________________________________________________________
# conv2d_2308 (Conv2D)            (None, 32, 32, 48)   13872       batch_normalization_2285[0][0]
# __________________________________________________________________________________________________
# elu_2151 (ELU)                  (None, 32, 32, 48)   0           conv2d_2270[0][0]
# __________________________________________________________________________________________________
# elu_2169 (ELU)                  (None, 32, 32, 48)   0           conv2d_2289[0][0]
# __________________________________________________________________________________________________
# elu_2187 (ELU)                  (None, 32, 32, 48)   0           conv2d_2308[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2250 (Batch (None, 32, 32, 48)   192         elu_2151[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2268 (Batch (None, 32, 32, 48)   192         elu_2169[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2286 (Batch (None, 32, 32, 48)   192         elu_2187[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_479 (MaxPooling2D (None, 16, 16, 48)   0           batch_normalization_2250[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_483 (MaxPooling2D (None, 16, 16, 48)   0           batch_normalization_2268[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_487 (MaxPooling2D (None, 16, 16, 48)   0           batch_normalization_2286[0][0]
# __________________________________________________________________________________________________
# conv2d_2271 (Conv2D)            (None, 16, 16, 48)   20784       max_pooling2d_479[0][0]
# __________________________________________________________________________________________________
# conv2d_2290 (Conv2D)            (None, 16, 16, 48)   20784       max_pooling2d_483[0][0]
# __________________________________________________________________________________________________
# conv2d_2309 (Conv2D)            (None, 16, 16, 48)   20784       max_pooling2d_487[0][0]
# __________________________________________________________________________________________________
# elu_2152 (ELU)                  (None, 16, 16, 48)   0           conv2d_2271[0][0]
# __________________________________________________________________________________________________
# elu_2170 (ELU)                  (None, 16, 16, 48)   0           conv2d_2290[0][0]
# __________________________________________________________________________________________________
# elu_2188 (ELU)                  (None, 16, 16, 48)   0           conv2d_2309[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2251 (Batch (None, 16, 16, 48)   192         elu_2152[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2269 (Batch (None, 16, 16, 48)   192         elu_2170[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2287 (Batch (None, 16, 16, 48)   192         elu_2188[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_476 (UpSampling2D (None, 32, 32, 48)   0           batch_normalization_2251[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_480 (UpSampling2D (None, 32, 32, 48)   0           batch_normalization_2269[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_484 (UpSampling2D (None, 32, 32, 48)   0           batch_normalization_2287[0][0]
# __________________________________________________________________________________________________
# concatenate_528 (Concatenate)   (None, 32, 32, 96)   0           batch_normalization_2250[0][0]
#                                                                  up_sampling2d_476[0][0]
# __________________________________________________________________________________________________
# concatenate_532 (Concatenate)   (None, 32, 32, 96)   0           batch_normalization_2268[0][0]
#                                                                  up_sampling2d_480[0][0]
# __________________________________________________________________________________________________
# concatenate_536 (Concatenate)   (None, 32, 32, 96)   0           batch_normalization_2286[0][0]
#                                                                  up_sampling2d_484[0][0]
# __________________________________________________________________________________________________
# conv2d_2272 (Conv2D)            (None, 32, 32, 32)   27680       concatenate_528[0][0]
# __________________________________________________________________________________________________
# conv2d_2291 (Conv2D)            (None, 32, 32, 32)   27680       concatenate_532[0][0]
# __________________________________________________________________________________________________
# conv2d_2310 (Conv2D)            (None, 32, 32, 32)   27680       concatenate_536[0][0]
# __________________________________________________________________________________________________
# elu_2153 (ELU)                  (None, 32, 32, 32)   0           conv2d_2272[0][0]
# __________________________________________________________________________________________________
# elu_2171 (ELU)                  (None, 32, 32, 32)   0           conv2d_2291[0][0]
# __________________________________________________________________________________________________
# elu_2189 (ELU)                  (None, 32, 32, 32)   0           conv2d_2310[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2252 (Batch (None, 32, 32, 32)   128         elu_2153[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2270 (Batch (None, 32, 32, 32)   128         elu_2171[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2288 (Batch (None, 32, 32, 32)   128         elu_2189[0][0]
# __________________________________________________________________________________________________
# conv2d_2273 (Conv2D)            (None, 32, 32, 32)   9248        batch_normalization_2252[0][0]
# __________________________________________________________________________________________________
# conv2d_2292 (Conv2D)            (None, 32, 32, 32)   9248        batch_normalization_2270[0][0]
# __________________________________________________________________________________________________
# conv2d_2311 (Conv2D)            (None, 32, 32, 32)   9248        batch_normalization_2288[0][0]
# __________________________________________________________________________________________________
# elu_2154 (ELU)                  (None, 32, 32, 32)   0           conv2d_2273[0][0]
# __________________________________________________________________________________________________
# elu_2172 (ELU)                  (None, 32, 32, 32)   0           conv2d_2292[0][0]
# __________________________________________________________________________________________________
# elu_2190 (ELU)                  (None, 32, 32, 32)   0           conv2d_2311[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2253 (Batch (None, 32, 32, 32)   128         elu_2154[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2271 (Batch (None, 32, 32, 32)   128         elu_2172[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2289 (Batch (None, 32, 32, 32)   128         elu_2190[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_477 (UpSampling2D (None, 64, 64, 32)   0           batch_normalization_2253[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_481 (UpSampling2D (None, 64, 64, 32)   0           batch_normalization_2271[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_485 (UpSampling2D (None, 64, 64, 32)   0           batch_normalization_2289[0][0]
# __________________________________________________________________________________________________
# concatenate_529 (Concatenate)   (None, 64, 64, 64)   0           batch_normalization_2247[0][0]
#                                                                  up_sampling2d_477[0][0]
# __________________________________________________________________________________________________
# concatenate_533 (Concatenate)   (None, 64, 64, 64)   0           batch_normalization_2265[0][0]
#                                                                  up_sampling2d_481[0][0]
# __________________________________________________________________________________________________
# concatenate_537 (Concatenate)   (None, 64, 64, 64)   0           batch_normalization_2283[0][0]
#                                                                  up_sampling2d_485[0][0]
# __________________________________________________________________________________________________
# conv2d_2274 (Conv2D)            (None, 64, 64, 16)   9232        concatenate_529[0][0]
# __________________________________________________________________________________________________
# conv2d_2293 (Conv2D)            (None, 64, 64, 16)   9232        concatenate_533[0][0]
# __________________________________________________________________________________________________
# conv2d_2312 (Conv2D)            (None, 64, 64, 16)   9232        concatenate_537[0][0]
# __________________________________________________________________________________________________
# elu_2155 (ELU)                  (None, 64, 64, 16)   0           conv2d_2274[0][0]
# __________________________________________________________________________________________________
# elu_2173 (ELU)                  (None, 64, 64, 16)   0           conv2d_2293[0][0]
# __________________________________________________________________________________________________
# elu_2191 (ELU)                  (None, 64, 64, 16)   0           conv2d_2312[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2254 (Batch (None, 64, 64, 16)   64          elu_2155[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2272 (Batch (None, 64, 64, 16)   64          elu_2173[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2290 (Batch (None, 64, 64, 16)   64          elu_2191[0][0]
# __________________________________________________________________________________________________
# conv2d_2275 (Conv2D)            (None, 64, 64, 16)   2320        batch_normalization_2254[0][0]
# __________________________________________________________________________________________________
# conv2d_2294 (Conv2D)            (None, 64, 64, 16)   2320        batch_normalization_2272[0][0]
# __________________________________________________________________________________________________
# conv2d_2313 (Conv2D)            (None, 64, 64, 16)   2320        batch_normalization_2290[0][0]
# __________________________________________________________________________________________________
# elu_2156 (ELU)                  (None, 64, 64, 16)   0           conv2d_2275[0][0]
# __________________________________________________________________________________________________
# elu_2174 (ELU)                  (None, 64, 64, 16)   0           conv2d_2294[0][0]
# __________________________________________________________________________________________________
# elu_2192 (ELU)                  (None, 64, 64, 16)   0           conv2d_2313[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2255 (Batch (None, 64, 64, 16)   64          elu_2156[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2273 (Batch (None, 64, 64, 16)   64          elu_2174[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2291 (Batch (None, 64, 64, 16)   64          elu_2192[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_478 (UpSampling2D (None, 128, 128, 16) 0           batch_normalization_2255[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_482 (UpSampling2D (None, 128, 128, 16) 0           batch_normalization_2273[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_486 (UpSampling2D (None, 128, 128, 16) 0           batch_normalization_2291[0][0]
# __________________________________________________________________________________________________
# concatenate_530 (Concatenate)   (None, 128, 128, 32) 0           batch_normalization_2244[0][0]
#                                                                  up_sampling2d_478[0][0]
# __________________________________________________________________________________________________
# concatenate_534 (Concatenate)   (None, 128, 128, 32) 0           batch_normalization_2262[0][0]
#                                                                  up_sampling2d_482[0][0]
# __________________________________________________________________________________________________
# concatenate_538 (Concatenate)   (None, 128, 128, 32) 0           batch_normalization_2280[0][0]
#                                                                  up_sampling2d_486[0][0]
# __________________________________________________________________________________________________
# conv2d_2276 (Conv2D)            (None, 128, 128, 8)  2312        concatenate_530[0][0]
# __________________________________________________________________________________________________
# conv2d_2295 (Conv2D)            (None, 128, 128, 8)  2312        concatenate_534[0][0]
# __________________________________________________________________________________________________
# conv2d_2314 (Conv2D)            (None, 128, 128, 8)  2312        concatenate_538[0][0]
# __________________________________________________________________________________________________
# elu_2157 (ELU)                  (None, 128, 128, 8)  0           conv2d_2276[0][0]
# __________________________________________________________________________________________________
# elu_2175 (ELU)                  (None, 128, 128, 8)  0           conv2d_2295[0][0]
# __________________________________________________________________________________________________
# elu_2193 (ELU)                  (None, 128, 128, 8)  0           conv2d_2314[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2256 (Batch (None, 128, 128, 8)  32          elu_2157[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2274 (Batch (None, 128, 128, 8)  32          elu_2175[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2292 (Batch (None, 128, 128, 8)  32          elu_2193[0][0]
# __________________________________________________________________________________________________
# conv2d_2277 (Conv2D)            (None, 128, 128, 8)  584         batch_normalization_2256[0][0]
# __________________________________________________________________________________________________
# conv2d_2296 (Conv2D)            (None, 128, 128, 8)  584         batch_normalization_2274[0][0]
# __________________________________________________________________________________________________
# conv2d_2315 (Conv2D)            (None, 128, 128, 8)  584         batch_normalization_2292[0][0]
# __________________________________________________________________________________________________
# elu_2158 (ELU)                  (None, 128, 128, 8)  0           conv2d_2277[0][0]
# __________________________________________________________________________________________________
# elu_2176 (ELU)                  (None, 128, 128, 8)  0           conv2d_2296[0][0]
# __________________________________________________________________________________________________
# elu_2194 (ELU)                  (None, 128, 128, 8)  0           conv2d_2315[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2257 (Batch (None, 128, 128, 8)  32          elu_2158[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2275 (Batch (None, 128, 128, 8)  32          elu_2176[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2293 (Batch (None, 128, 128, 8)  32          elu_2194[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_479 (UpSampling2D (None, 256, 256, 8)  0           batch_normalization_2257[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_483 (UpSampling2D (None, 256, 256, 8)  0           batch_normalization_2275[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_487 (UpSampling2D (None, 256, 256, 8)  0           batch_normalization_2293[0][0]
# __________________________________________________________________________________________________
# concatenate_531 (Concatenate)   (None, 256, 256, 16) 0           batch_normalization_2242[0][0]
#                                                                  up_sampling2d_479[0][0]
# __________________________________________________________________________________________________
# concatenate_535 (Concatenate)   (None, 256, 256, 16) 0           batch_normalization_2260[0][0]
#                                                                  up_sampling2d_483[0][0]
# __________________________________________________________________________________________________
# concatenate_539 (Concatenate)   (None, 256, 256, 16) 0           batch_normalization_2278[0][0]
#                                                                  up_sampling2d_487[0][0]
# __________________________________________________________________________________________________
# conv2d_2278 (Conv2D)            (None, 256, 256, 4)  68          concatenate_531[0][0]
# __________________________________________________________________________________________________
# conv2d_2297 (Conv2D)            (None, 256, 256, 4)  68          concatenate_535[0][0]
# __________________________________________________________________________________________________
# conv2d_2316 (Conv2D)            (None, 256, 256, 4)  68          concatenate_539[0][0]
# __________________________________________________________________________________________________
# elu_2159 (ELU)                  (None, 256, 256, 4)  0           conv2d_2278[0][0]
# __________________________________________________________________________________________________
# elu_2177 (ELU)                  (None, 256, 256, 4)  0           conv2d_2297[0][0]
# __________________________________________________________________________________________________
# elu_2195 (ELU)                  (None, 256, 256, 4)  0           conv2d_2316[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2258 (Batch (None, 256, 256, 4)  16          elu_2159[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2276 (Batch (None, 256, 256, 4)  16          elu_2177[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2294 (Batch (None, 256, 256, 4)  16          elu_2195[0][0]
# __________________________________________________________________________________________________
# boundary_input (InputLayer)     [(None, 256, 256, 1) 0
# __________________________________________________________________________________________________
# conv2d_2279 (Conv2D)            (None, 256, 256, 1)  5           batch_normalization_2258[0][0]
# __________________________________________________________________________________________________
# conv2d_2298 (Conv2D)            (None, 256, 256, 1)  5           batch_normalization_2276[0][0]
# __________________________________________________________________________________________________
# conv2d_2317 (Conv2D)            (None, 256, 256, 1)  5           batch_normalization_2294[0][0]
# __________________________________________________________________________________________________
# multiply_123 (Multiply)         (None, 256, 256, 1)  0           conv2d_2279[0][0]
#                                                                  boundary_input[0][0]
# __________________________________________________________________________________________________
# multiply_124 (Multiply)         (None, 256, 256, 1)  0           conv2d_2298[0][0]
#                                                                  boundary_input[0][0]
# __________________________________________________________________________________________________
# multiply_125 (Multiply)         (None, 256, 256, 1)  0           conv2d_2317[0][0]
#                                                                  boundary_input[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_102 (TFOpLambda) (None, 1, 256, 256,  0           multiply_123[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_103 (TFOpLambda) (None, 1, 256, 256,  0           multiply_124[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_104 (TFOpLambda) (None, 1, 256, 256,  0           multiply_125[0][0]
# __________________________________________________________________________________________________
# concatenate_540 (Concatenate)   (None, 3, 256, 256,  0           tf.expand_dims_102[0][0]
#                                                                  tf.expand_dims_103[0][0]
#                                                                  tf.expand_dims_104[0][0]
# __________________________________________________________________________________________________
# conv_lst_m2d_99 (ConvLSTM2D)    (None, 3, 256, 256,  27264       concatenate_540[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2295 (Batch (None, 3, 256, 256,  64          conv_lst_m2d_99[0][0]
# __________________________________________________________________________________________________
# conv_lst_m2d_100 (ConvLSTM2D)   (None, 3, 256, 256,  18496       batch_normalization_2295[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2296 (Batch (None, 3, 256, 256,  64          conv_lst_m2d_100[0][0]
# __________________________________________________________________________________________________
# conv_lst_m2d_101 (ConvLSTM2D)   (None, 3, 256, 256,  2112        batch_normalization_2296[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2297 (Batch (None, 3, 256, 256,  64          conv_lst_m2d_101[0][0]
# __________________________________________________________________________________________________
# conv3d_33 (Conv3D)              (None, 3, 256, 256,  433         batch_normalization_2297[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_69 (Sl (None, 256, 256, 1)  0           conv3d_33[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_70 (Sl (None, 256, 256, 1)  0           conv3d_33[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_71 (Sl (None, 256, 256, 1)  0           conv3d_33[0][0]
# __________________________________________________________________________________________________
# multiply_126 (Multiply)         (None, 256, 256, 1)  0           boundary_input[0][0]
#                                                                  tf.__operators__.getitem_69[0][0]
# __________________________________________________________________________________________________
# multiply_127 (Multiply)         (None, 256, 256, 1)  0           boundary_input[0][0]
#                                                                  tf.__operators__.getitem_70[0][0]
# __________________________________________________________________________________________________
# multiply_128 (Multiply)         (None, 256, 256, 1)  0           boundary_input[0][0]
#                                                                  tf.__operators__.getitem_71[0][0]
# __________________________________________________________________________________________________
# concatenate_541 (Concatenate)   (None, 256, 256, 3)  0           multiply_126[0][0]
#                                                                  multiply_127[0][0]
#                                                                  multiply_128[0][0]
# ==================================================================================================
# Total params: 400,484
# Trainable params: 397,868
# Non-trainable params: 2,616
# __________________________________________________________________________________________________

# %%
train_steps = len(image0_train_generator)
val_steps = len(image0_val_generator)

history = model.fit(train_generator, validation_data=val_generator, 
                    steps_per_epoch=train_steps, validation_steps=val_steps, 
                    epochs = 5, verbose=1, callbacks=[checkpoint, lr_callback])
# Out:
# Epoch 1/5
# 308/308 [==============================] - 53s 145ms/step - loss: 2.2510 - mean_io_u_33: 0.4797 - val_loss: 2.0364 - val_mean_io_u_33: 0.4806
#
# Epoch 00001: val_loss did not improve from 1.00026
# Epoch 2/5
# 308/308 [==============================] - 45s 145ms/step - loss: 2.1824 - mean_io_u_33: 0.4793 - val_loss: 2.0928 - val_mean_io_u_33: 0.4855
#
# Epoch 00002: val_loss did not improve from 1.00026
# Epoch 3/5
# 308/308 [==============================] - 47s 151ms/step - loss: 2.1301 - mean_io_u_33: 0.4800 - val_loss: 2.1023 - val_mean_io_u_33: 0.4822
#
# Epoch 00003: val_loss did not improve from 1.00026
# Epoch 4/5
# 308/308 [==============================] - 47s 154ms/step - loss: 2.0908 - mean_io_u_33: 0.4795 - val_loss: 2.0823 - val_mean_io_u_33: 0.4846
#
# Epoch 00004: val_loss did not improve from 1.00026
# Epoch 5/5
# 222/308 [====================>.........] - ETA: 12s - loss: 2.0641 - mean_io_u_33: 0.4780
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-473-edde1a5e0ae5> in <module>
#       2 val_steps = len(image0_val_generator)
#       3
# ----> 4 history = model.fit(train_generator, validation_data=val_generator,
#       5                     steps_per_epoch=train_steps, validation_steps=val_steps,
#       6                     epochs = 5, verbose=1, callbacks=[checkpoint, lr_callback])
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1181                 _r=1):
#    1182               callbacks.on_train_batch_begin(step)
# -> 1183               tmp_logs = self.train_function(iterator)
#    1184               if data_handler.should_sync:
#    1185                 context.async_wait()
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     887
#     888       with OptionalXlaContext(self._jit_compile):
# --> 889         result = self._call(*args, **kwds)
#     890
#     891       new_tracing_count = self.experimental_get_tracing_count()
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     915       # In this case we have created variables on the first call, so we run the
#     916       # defunned version which is guaranteed to never create variables.
# --> 917       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     918     elif self._stateful_fn is not None:
#     919       # Release the lock early so that multiple threads can perform the call
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    3021       (graph_function,
#    3022        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 3023     return graph_function._call_flat(
#    3024         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    3025
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1958         and executing_eagerly):
#    1959       # No tape is watching; skip to running the function.
# -> 1960       return self._build_call_outputs(self._inference_function.call(
#    1961           ctx, args, cancellation_manager=cancellation_manager))
#    1962     forward_backward = self._select_forward_and_backward_functions(
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     589       with _InterpolateFunctionError(self):
#     590         if cancellation_manager is None:
# --> 591           outputs = execute.execute(
#     592               str(self.signature.name),
#     593               num_outputs=self._num_outputs,
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57   try:
#      58     ctx.ensure_initialized()
# ---> 59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
plt.figure()
plt.plot(history.history['mean_io_u_32'], label = 'Train IOU')
plt.plot(history.history['val_mean_io_u_32'], label = 'Val IOU')
plt.title('Mean IOU')
plt.legend()

plt.figure()
plt.plot(history.history['loss'], label = 'Train loss')
plt.plot(history.history['val_loss'], label = 'Val loss')
plt.title('loss')
plt.legend()

# %%
max_show = 1
test_iter = iter(test_generator)
for i in range(max_show):
    images, masks = next(test_iter)
    print(masks.shape)
    pred_masks = model.predict(images)
    fig, ax = plt.subplots(1, 3, figsize=(15, 6))
    for a in ax:
        a.axis('off')

    ax[0].imshow(images[i][0])
    ax[0].set_title('Original')
    ax[1].imshow(pred_masks[i])
    ax[1].set_title('Prediction')
    
    ax[2].imshow(masks[i])
    ax[2].set_title('Ground truth')
    #plt.savefig(f"pred_{i}.jpg", dpi=150)
    plt.show()
